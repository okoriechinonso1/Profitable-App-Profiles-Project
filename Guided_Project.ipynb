# %% [markdown]
# # Analyzing Mobile App Data

# %% [markdown]
# - Goal for the project is to analyze data to help app developers understand what type of apps are likely to attract more users.

# %% [markdown]
# ## Data Exploration
#
# - A dataset containing data about approximately 10,000 Android apps from Google Play; the data was collected in August 2018.
#
# - A dataset containing data about approximately 7,000 iOS apps from the App Store; the data was collected in July 2017. Find information on the data below
#
# I start by opening and exploring the two datasets. I created a function that can used to explore the rows in each of the datasets

# %%
# Opening the AppleStore data
opened_file = open('AppleStore.csv', 'r')
from csv import reader
read_file = reader(opened_file)
apples_data = list(read_file)
apples_header = apples_data[0]
apples_data = apples_data[1:]


# Opening the googleplaystore data
opened_file = open('googleplaystore.csv', 'r')
read_file = reader(opened_file)
google_data = list(read_file)
google_header = google_data[0]
google_data = google_data[1:]

# %%
def explore_data(dataset, first, last, header=False):
    dataset_slice = dataset[first:last]
    
    for row in dataset_slice:
        print(row)
        print('\n')
        
        if header:
            print('Number of rows:', len(dataset))
            print('Number of columns:', len(dataset[0]))

# %%
first_dataset = explore_data(apples_data, 0, 3, True)
print(first_dataset)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 7197
# Number of columns: 16
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# Number of rows: 7197
# Number of columns: 16
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 7197
# Number of columns: 16
# None

# %%
second_dataset = explore_data(google_data, 2, 8, True)
print(second_dataset)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# ['Infinite Painter', 'ART_AND_DESIGN', '4.1', '36815', '29M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'June 14, 2018', '6.1.61.1', '4.2 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# None

# %% [markdown]
# Exploring the column headers of the two datasets

# %%
apples_header
# Out:
# ['id',
#  'track_name',
#  'size_bytes',
#  'currency',
#  'price',
#  'rating_count_tot',
#  'rating_count_ver',
#  'user_rating',
#  'user_rating_ver',
#  'ver',
#  'cont_rating',
#  'prime_genre',
#  'sup_devices.num',
#  'ipadSc_urls.num',
#  'lang.num',
#  'vpp_lic']

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Deleting Wrong Data
#
# - Detect inaccurate data, and correct or remove it
# - Detect duplicate data, and remove the duplicates
# - Removing non-English apps like 爱奇艺PPS -《欢乐颂2》电视剧热播.
# - Removing apps that aren't free

# %%
google_header
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
for row in google_data:
    if len(row) != len(google_data[0]):
        print(row)
        
        print('\n')
        print('The index position is:', google_data.index(row))
        print('The number of datapoints in this row is:', len(row))
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# The index position is: 10472
# The number of datapoints in this row is: 12

# %%
# Deleting the wrong data entry at that index position

del google_data[10472]

# %% [markdown]
# ### Checking for duplicate Entries
#
# - Some Apps have duplicate entries, we will inspect and remove these entries from our datasets

# %%
duplicate_apps = []
unique_apps = []

count = 0
for app in google_data:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
        if count <= 5:
            print(app)
        count+=1
        
    else:
        unique_apps.append(name)
        
print('Number of duplicate apps:', len(duplicate_apps))
print('\n')
print('Examples of duplicate apps:', duplicate_apps[:15])
# Out:
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
# ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '4.1.28165.0716', '4.0 and up']
# ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %%
print('Expected length:', len(google_data) - 1181)
# Out:
# Expected length: 9659

# %%
reviews_max = {}
for app in google_data:
    name = app[0]
    n_reviews = float(app[3])
        
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    if name not in reviews_max:
        reviews_max[name] = n_reviews
        
print(len(reviews_max))
# Out:
# 9659

# %% [markdown]
# Removing Duplicate Entries

# %%
# Removing duplicate rows

android_clean = []
already_added = []

for item in google_data:
    name = item[0]
    reviews = app[3]
    if 'M' in reviews:
        reviews = reviews.rstrip('M')
        n_reviews = float(reviews)

    if (n_reviews == reviews_max[name]) and (name not in already_added):
        android_clean.append(item)
        already_added.append(name)
    
                
print(len(android_clean))
# Out:
# 9659

# %%
applestore_duplicates = []
unique_entries = []

for app in apples_data:
    name = app[0]
    if name in unique_entries:
        applestore_duplicates.append(name)
    else:
        unique_entries.append(name)

# %%
print(len(applestore_duplicates))
# Out:
# 0

# %% [markdown]
# Seems there are no duplicate entries in the appleStore data

# %%
def string_func(string):
    count = 0
    for element in string:
        if ord(element) > 127:
            count += 1
    if count > 3:
        return False
    else:
        return True
    return None

# %%
name = string_func('Instachat 😜')
docs = string_func('Docs To Go™ Free Office Suite')
chinese_lang = string_func('爱奇艺PPS -《欢乐颂2》电视剧热播')
new = string_func("Free Office Suite")

print(name)
print(docs)
print(chinese_lang)
print(new)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ## Filtering out non-english apps

# %%
# Filtering out non-English apps from both the Android apps data and the IOS apps data
english_apps = []
non_english_apps = []

for element in google_data:
    name = element[0]
    english_chr_app = string_func(name)
    if english_chr_app is True:
        english_apps.append(element)
    else:
        non_english_apps.append(element)
        
ios_english_apps = []
ios_non_english_apps = []

for item in apples_data:
    name = item[0]
    english_chr_app = string_func(name)
    if english_chr_app is True:
        ios_english_apps.append(item)
    else:
        ios_non_english_apps.append(name)

print(len(ios_english_apps))
print(len(ios_non_english_apps))
# Out:
# 7197
# 0

# %%
print('Number of english apps in the android dataset is:', len(english_apps))
print('Number of non_english apps in the android dataset is:', len(non_english_apps))
print('\n')
print('Number of english apps in the ios apps dataset:', len(ios_english_apps))
print('Number of non english apps in the ios apps dataset:', len(ios_non_english_apps))
# Out:
# Number of english apps in the android dataset is: 10795
# Number of non_english apps in the android dataset is: 45
#
#
# Number of english apps in the ios apps dataset: 7197
# Number of non english apps in the ios apps dataset: 0

# %% [markdown]
# ### Isolting the Free Apps
#
# we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our datasets contain both free and non-free apps; we'll need to isolate only the free apps for our analysis

# %%
# Isolating free apps from non-free for the google dataset
free_apps = []
non_free_apps = []


for element in google_data:
    app_price = element[7]
    if app_price == '0':
        free_apps.append(element)
    else:
        non_free_apps.append(element)
print('Number of free android apps:', len(free_apps))


# Isolating free apps from non free apps for the IOS dataset
free_ios_apps = []
non_free_ios_apps = []

for element in apples_data:
    app_price = element[4]
    if app_price == '0.0':
        free_ios_apps.append(element)
    else:
        non_free_ios_apps.append(element)


print('Number of free IOS apps:', len(free_ios_apps))
# Out:
# Number of free android apps: 10040
# Number of free IOS apps: 4056

# %% [markdown]
# As we mentioned in the introduction, our goal is to determine the kinds of apps that are likely to attract more users because the number of people using our apps affect our revenue.
#
# To minimize risks and overhead, our validation strategy for an app idea has three steps:
# - Build a minimal Android version of the app, and add it to Google Play.
# - If the app has a good response from users, we develop it further.
# - If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# Because our end goal is to add the app on both Google Play and the App Store, we need to find app profiles that are successful in both markets. For instance, a profile that works well for both markets might be a productivity app that makes use of gamification.

# %%
google_header
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
apples_header
# Out:
# ['id',
#  'track_name',
#  'size_bytes',
#  'currency',
#  'price',
#  'rating_count_tot',
#  'rating_count_ver',
#  'user_rating',
#  'user_rating_ver',
#  'ver',
#  'cont_rating',
#  'prime_genre',
#  'sup_devices.num',
#  'ipadSc_urls.num',
#  'lang.num',
#  'vpp_lic']

# %%
apples_header.index('rating_count_tot')
# Out:
# 5

# %% [markdown]
# Building a frequency table for the google play store using 'Genres; column and 'Category' column and for the Apples Store using the prime_genre

# %%
# Changing the variable name of google and IOS header columns to free apps for google and IOS

free_apps_header = google_header
free_ios_header = apples_header

# %%
free_apps_header.index('Genres')
# Out:
# 9

# %%
free_ios_header.index('prime_genre')
# Out:
# 11

# %%
free_apps_header.index('Category')
# Out:
# 1

# %%
def freq_table(dataset, index):
    genres = {}
    total_number_of_apps = 0
    
    for element in dataset:
        total_number_of_apps += 1
        genre = element[index]
        
        if genre in genres:
            genres[genre] += 1
        else:
            genres[genre] = 1
            
    genres_percent = {}        
    for key in genres:
        percentage = (genres[key] / total_number_of_apps) * 100
        genres_percent[key] = round(percentage, 3)
    
    return genres_percent


    
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_value_tuple = (table[key], key) # takes each key-value pair and stores it as a tuple
        table_display.append(key_value_tuple)
    
    table_sorted = sorted(table_display, reverse=True)
    for entry in table_sorted:
        print(entry[1], entry[0])

# %% [markdown]
# ### Analyzing the prime_genre apps from the Apples store

# %%
prime_genre = display_table(free_ios_apps, 11)
# Out:
# Games 55.646
# Entertainment 8.235
# Photo & Video 4.117
# Social Networking 3.526
# Education 3.254
# Shopping 2.983
# Utilities 2.687
# Lifestyle 2.318
# Finance 2.071
# Sports 1.948
# Health & Fitness 1.874
# Music 1.652
# Book 1.627
# Productivity 1.529
# News 1.43
# Travel 1.381
# Food & Drink 1.06
# Weather 0.764
# Reference 0.493
# Navigation 0.493
# Business 0.493
# Catalogs 0.222
# Medical 0.197

# %% [markdown]
# - We can see that more than half (58.16%) of the free English apps are games. Photo and video applications come in at about 5%, followed by entertainment apps at about 8%. Social networking apps account for 3.29% of the apps in our data collection, trailing only educational apps with 3.66% of the total.
# - Apps with recreational purposes (games, entertainment, photo and video, social networking, sports, music, etc.) predominate in the App Store (at least the portion of it that offers free English apps), while apps with more practical purposes (education, shopping, utilities, productivity, lifestyle, etc.) are less common. However, just because there are more enjoyable apps available doesn't necessarily mean that there are more users as well; demand and supply might not line up perfectly.

# %% [markdown]
# ### Analyzing the frequency table generated from category and genres

# %%
genre = display_table(free_apps, 9)
# Out:
# Tools 7.61
# Entertainment 6.016
# Education 5.169
# Business 4.442
# Productivity 3.944
# Sports 3.725
# Lifestyle 3.606
# Communication 3.586
# Medical 3.526
# Finance 3.476
# Action 3.396
# Health & Fitness 3.237
# Photography 3.118
# Personalization 3.078
# Social 2.908
# News & Magazines 2.799
# Shopping 2.57
# Travel & Local 2.44
# Dating 2.261
# Books & Reference 2.022
# Arcade 1.992
# Simulation 1.902
# Casual 1.833
# Video Players & Editors 1.683
# Maps & Navigation 1.315
# Food & Drink 1.245
# Puzzle 1.205
# Racing 0.946
# Strategy 0.936
# House & Home 0.876
# Role Playing 0.867
# Libraries & Demo 0.837
# Auto & Vehicles 0.817
# Weather 0.737
# Events 0.627
# Adventure 0.627
# Comics 0.588
# Art & Design 0.548
# Beauty 0.528
# Parenting 0.438
# Education;Education 0.438
# Card 0.408
# Trivia 0.378
# Educational;Education 0.378
# Casino 0.378
# Board 0.349
# Educational 0.329
# Word 0.289
# Entertainment;Music & Video 0.269
# Casual;Pretend Play 0.249
# Music 0.209
# Casual;Action & Adventure 0.199
# Racing;Action & Adventure 0.189
# Puzzle;Brain Games 0.169
# Educational;Pretend Play 0.139
# Action;Action & Adventure 0.139
# Casual;Brain Games 0.129
# Arcade;Action & Adventure 0.12
# Simulation;Action & Adventure 0.11
# Adventure;Action & Adventure 0.11
# Entertainment;Brain Games 0.08
# Education;Pretend Play 0.08
# Board;Brain Games 0.08
# Parenting;Education 0.07
# Casual;Creativity 0.07
# Art & Design;Creativity 0.07
# Role Playing;Action & Adventure 0.06
# Parenting;Music & Video 0.06
# Educational;Brain Games 0.06
# Role Playing;Pretend Play 0.05
# Puzzle;Action & Adventure 0.05
# Education;Music & Video 0.05
# Education;Creativity 0.05
# Educational;Action & Adventure 0.04
# Education;Brain Games 0.04
# Education;Action & Adventure 0.04
# Video Players & Editors;Music & Video 0.03
# Simulation;Pretend Play 0.03
# Entertainment;Creativity 0.03
# Entertainment;Action & Adventure 0.03
# Educational;Creativity 0.03
# Video Players & Editors;Creativity 0.02
# Sports;Action & Adventure 0.02
# Puzzle;Creativity 0.02
# Music;Music & Video 0.02
# Entertainment;Pretend Play 0.02
# Casual;Music & Video 0.02
# Casual;Education 0.02
# Board;Action & Adventure 0.02
# Art & Design;Pretend Play 0.02
# Art & Design;Action & Adventure 0.02
# Adventure;Education 0.02
# Trivia;Education 0.01
# Travel & Local;Action & Adventure 0.01
# Tools;Education 0.01
# Strategy;Education 0.01
# Strategy;Creativity 0.01
# Strategy;Action & Adventure 0.01
# Simulation;Education 0.01
# Role Playing;Brain Games 0.01
# Racing;Pretend Play 0.01
# Puzzle;Education 0.01
# Parenting;Brain Games 0.01
# Music & Audio;Music & Video 0.01
# Lifestyle;Pretend Play 0.01
# Lifestyle;Education 0.01
# Health & Fitness;Education 0.01
# Health & Fitness;Action & Adventure 0.01
# Entertainment;Education 0.01
# Communication;Creativity 0.01
# Comics;Creativity 0.01
# Card;Brain Games 0.01
# Card;Action & Adventure 0.01
# Books & Reference;Education 0.01
# Arcade;Pretend Play 0.01

# %%
category = display_table(free_ios_apps, 1)
# Out:
# VR Roller Coaster 0.049
# Mannequin Challenge 0.049
# ｗｗｗ 0.025
# Ｘ:15秒の人気 アクション ゲーム 0.025
# ２ちゃんねる for iPhone 0.025
# 애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요! 0.025
# 실시간 날씨 0.025
# 龙珠直播-高清游戏娱乐直播平台 0.025
# 龙之觉醒-热血经典RPG，回味激燃岁月 0.025
# 黄金日-贵金属理财投资黄金白银 0.025
# 鴨川等間隔の法則 0.025
# 鳥として生きた男　その壮絶な人生 0.025
# 魔灵觉醒（王者归来）- 3D新职业魔剑士降临 0.025
# 鬼畜三国-红将觉醒 0.025
# 鬼畜-一亿人都在用的聊天必备神器! 0.025
# 鬼吹灯昆仑神宫 - 年兽袭来 0.025
# 鬼とび 0.025
# 高清影视-大片免费天天看 0.025
# 高德地图（精准专业的手机地图） 0.025
# 高德地图HD 0.025
# 驾考宝典-2017最新考驾照驾校学车驾考通 0.025
# 驾校一点通-保过版，2017最新驾考学车宝典 0.025
# 驴妈妈旅游-订景点门票机票火车票特价酒店 0.025
# 饿了么外卖-大牌美食，折扣热卖 0.025
# 食べないと死ぬ2 0.025
# 食べないと死ぬ 3 0.025
# 飞猪 0.025
# 飞凡--智慧新生活 0.025
# 飛べないロボはただの... ～無料アクションRPGゲーム～ 0.025
# 风行视频+ HD - 电影电视剧体育视频播放器 0.025
# 頭の回転をはやくする！脳トレ！Blackhole 0.025
# 面白ニュースを超快適に読める!!まとめのまとめMM 0.025
# 非诚勿扰-中国最大免费婚恋交友平台 0.025
# 青藍高校リア充部 0.025
# 青藍高校ヒモ部 0.025
# 霸王英雄传（吕布一统天下，演义三国群英杰传奇） 0.025
# 霸王卧龙传奇（全新转职系统，60种职业供你选择） 0.025
# 電車パズル ツメツメ - 通勤時間にピッタリ! 脳トレパズル 0.025
# 電球でテニスしてみた-無料で遊べるミニゲーム 0.025
# 零钱夺宝pro-新手99元红包助你1元购 0.025
# 陌爱神器-不闲聊！陌生人快速约见面平台 0.025
# 陌爱-最in全民交友神器！同城寂陌陌生帅哥美女视频聊天约会平台 0.025
# 陌恋-同城高颜值寂寞美女帅哥激情交友聊天神器！ 0.025
# 阴阳师-全区互通现世集结 0.025
# 闲鱼-让你的闲置游起来 0.025
# 闪瘦-健康减肥瘦身 0.025
# 闇金クリッカー 0.025
# 镜花缘：两世英雄情缘,数年问仙修道 0.025
# 镜花奇缘 - 最新诛仙类卡牌传奇手游游戏 0.025
# 银联钱包- 银行卡管家，扫码支付享优惠 0.025
# 铁路12306 0.025
# 钱妈妈理财-国企投资有保障的金融理财产品！ 0.025
# 鏡の中のプリンセス Love Palace 0.025
# 銀魂 公式連載アプリ〜銀魂の漫画が毎週１巻読めるアプリ〜 0.025
# 針の穴 0.025
# 金钱谷软件-活期手机金融投资理财平台! 0.025
# 金庸群侠传—全自由单机武侠RPG 0.025
# 酷我音乐HD-无损在线播放 0.025
# 都市异能小说-全本经典有声小说听书阅读神器 0.025
# 通信量チェッカー 0.025
# 途牛旅游-订机票酒店，查旅行景点门票 0.025
# 途家-全球公寓民宿预订平台 0.025
# 逍遥修仙-掌上360度自由视角经典仙侠动作游戏 0.025
# 迷你世界-国产精品沙盒联机生存建造游戏 0.025
# 返利-专注网购省钱的APP 0.025
# 达令全球好货－正品免税，带你购全球 0.025
# 转转-更专业的二手闲置交易平台 0.025
# 轩辕剑叁外传之天之痕-正版经典仙侠授权 0.025
# 车轮车友会—汇集养车、洗车、代驾、汽车头条、汽车用品的车友聊天分享之家 0.025
# 车轮查违章-2017全国车辆违章查询助手 0.025
# 輪ゴムでシュート！ - 無料で遊べるミニゲーム 0.025
# 超特訓！トミックゲーム！！ 0.025
# 超ヒモ理論 ～働きたくないでござる～ 0.025
# 赶集网-工作生活啥都有！ 0.025
# 赤ペン 提出カメラ 0.025
# 贝贝-8000万妈妈信赖的母婴正品特卖拼团商城 0.025
# 豪快ショット連発！爽快卓球ゲーム「サァァァ！」 0.025
# 豪快ショット連発！ストレス発散テニスゲーム「エアK」 0.025
# 豆瓣 0.025
# 诺诺镑客—让财富升值 0.025
# 诸神战纪竞技场：超神大冒险(无尽关 排行榜 动作类横版过关游戏) 0.025
# 讯飞输入法-智能语音输入和表情斗图神器 0.025
# 謝罪会見 0.025
# 謎解き赤い封筒 0.025
# 謎解き窓ガラスの跡 0.025
# 謎解き母からのメモ 0.025
# 謎解きロッカーの忘れ物 0.025
# 謎解きあの人からメール 0.025
# 謎解き[緋色探偵社と100の推理]メッセージアプリ風ノベルゲーム 0.025
# 謎解き2016 0.025
# 謎解き ジェスチャーゲーム - 何してる？ 0.025
# 謎解き 0.025
# 謎トレ 謎解き脳トレーニング 0.025
# 誰ガ為ノ世界~悲しみと始まりのユグドラシル~ 0.025
# 誰にもバレない！[秘密のアルバム]　無料で写真をロック！ 0.025
# 觉醒吧数码兽-被选召的孩子  超人气动漫  回合制卡牌策略养成 0.025
# 视吧-全民手机直播 0.025
# 街机格斗王 0.025
# 融360-贷款、信用卡、信用报告 0.025
# 蜜芽 - 生娃养娃上蜜芽 0.025
# 蜀山诛魔纪-古装恋爱仙侠动作手游·MMO端游品质 0.025
# 蚂蚁聚宝—蚂蚁金服旗下投资理财平台 0.025
# 虫虫大作战-经典休闲蛇蛇 0.025
# 虎牙直播HD-热门高清游戏互动直播平台 0.025
# 虎牙直播-热门高清游戏互动直播平台 0.025
# 蘑菇街-网红直播搭配的购物特卖平台 0.025
# 蒼の彼方のフォーリズム‐ETERNAL SKY- 0.025
# 萌店-朋友圈的美味生活 0.025
# 英雄Q传-穿越回合制卡牌手游，梦幻般的剧情，开启3D热血传奇人生 0.025
# 苏宁易购-新人专享大礼包 0.025
# 花粉儿-女性、母婴闲置交易平台 0.025
# 花火撮影 notepad Lite 0.025
# 花椒直播-高清美颜直播互动平台 0.025
# 花札Online 0.025
# 艶が～るプレミアム 女性向け恋愛ゲーム！乙女げーむ 0.025
# 舞妓ドリル 0.025
# 自転車ナビ by NAVITIME(ナビタイム) - 自転車のナビができるアプリ 0.025
# 自らデッドボール 0.025
# 腾讯视频HD-楚乔传,明日之子6月全网首播 0.025
# 腾讯视频-欢乐颂2全网首播 0.025
# 腾讯欢乐麻将全集 0.025
# 腾讯新闻HD-最资深的阅读软件 0.025
# 腾讯新闻-头条新闻热点资讯掌上阅读软件 0.025
# 腾讯手机管家-拦截骚扰电话的QQ安全助手 0.025
# 腾讯微云HD-安全备份共享文件和照片 0.025
# 腾讯微云-安全备份共享文件和照片 0.025
# 腾讯体育-NBA全网独播 0.025
# 腾讯WiFi管家-手机安全免费WiFi 0.025
# 脳トレ！パターンキューブ 0.025
# 脳トレ物理パズル【キタコレ！】～IQの限界に挑めるパズルゲーム～ktkr 0.025
# 脳トレ爽快パズル 激ムズ！和のひとふで書き Line 0.025
# 脳トレクロスワード -解けばIQがあがる!?無料パズルゲーム- 0.025
# 脱出ゲーム　都市伝説〜杉沢村からの脱出〜 0.025
# 脱出ゲーム　研究所からの脱出 0.025
# 脱出ゲーム　海底神殿からの脱出 0.025
# 脱出ゲーム　大正ロマン　女記者脱出譚 0.025
# 脱出ゲーム　ピラミッドからの脱出 0.025
# 脱出ゲーム　カリスマブラザーズのワクワク女子寮脱出大作戦 0.025
# 脱出ゲーム　わたしをみつけて　-おじいさんとわたしの物語- 0.025
# 脱出ゲーム　ぼくのおねがいきいて 0.025
# 脱出ゲーム　Night Room 0.025
# 脱出ゲーム　In My Heart 0.025
# 脱出ゲーム　Cottage 0.025
# 脱出ゲーム 謎解き部屋からの脱出 0.025
# 脱出ゲーム 気まぐれカフェの謎解きタイム 0.025
# 脱出ゲーム 心霊学校からの脱出 0.025
# 脱出ゲーム 学校の食堂からの脱出 0.025
# 脱出ゲーム 学校の七不思議 -恐怖からの脱出- 0.025
# 脱出ゲーム 古城からの脱出 0.025
# 脱出ゲーム 体育館からの脱出【学校脱出シリーズ5弾】 0.025
# 脱出ゲーム Toilet 0.025
# 脱出ゲーム Oden 0.025
# 脱出ゲーム KOTATSU 0.025
# 脱出ゲーム KA-MA-KU-RA 0.025
# 脱出ゲーム 1K 0.025
# 脱出ゲーム - 書道教室 -  "漢字"の謎に満ちた部屋からの 脱出 0.025
# 脱出ゲーム - Solid - 無機質な部屋からの 脱出 0.025
# 脱出ゲーム - KINDERGARTEN - 子供にイタズラされたリビングからの 脱出 0.025
# 肌年齢診断 0.025
# 聚美优品-新用户专享160元现金券 0.025
# 聚力视频HD-人民的名义,跨界歌王全网热播 0.025
# 聚力视频-蓝光电视剧电影在线热播 0.025
# 翼支付-只为简单生活 0.025
# 美男美女診断 0.025
# 美柚 - 女生助手 0.025
# 美播 - 玩不尽的真人游戏 0.025
# 美团外卖-甜点生鲜等零食配送，鲜花蛋糕准时必达 0.025
# 美团 - 吃喝玩乐全都有 0.025
# 美丽说-潮流穿搭快人一步 0.025
# 罪と罰2 -犯人は誰だ!?- 謎解き推理ミステリーサスペンス 0.025
# 网易考拉海购—新人免费领取1000元优惠券 0.025
# 网易新闻 - 精选好内容，算出你的兴趣 0.025
# 网娱大师-网吧娱乐大师 0.025
# 网商银行 0.025
# 絶対に笑える話　腹筋崩壊の笑える話 0.025
# 紫马财行理财精英版—安全可靠的投资理财平台 0.025
# 素飛び 0.025
# 精度93％ 絶望の心理テスト 0.025
# 筆姫 - オシャレなグリーティングカード SNS投稿 自宅印刷もOK 0.025
# 笑ったら負け 0.025
# 競馬予想 アプリ！馬券予想で収支アップ！競馬 jra 攻略！ 0.025
# 空格－更优秀的个人技能交易平台 0.025
# 秘密の関係はじめました メッセージ風恋愛ゲーム 0.025
# 秒速で1億円 貢ぐ男　～美女キャラ集結！from ギャングロード JOKER～ 0.025
# 秒速 0.025
# 秒拍-超火爆短视频分享平台 0.025
# 秒で100億円 0.025
# 私のヒモ男～イケメン拾いました～恋愛・放置ゲーム 0.025
# 秀色秀场-网红直播 聊天交友 0.025
# 知乎 0.025
# 直播吧(官方版)-体育从这里开始 0.025
# 目の錯覚で性格診断 0.025
# 盗墓之王-寻龙秘事 0.025
# 盗墓OL-精绝女王 0.025
# 皮皮四川麻将 0.025
# 百盈足球-专业足篮比分赛事预测 0.025
# 百度钱包-金融信贷和理财投资优选 0.025
# 百度贴吧HD 0.025
# 百度贴吧-全球最大兴趣交友社区 0.025
# 百度视频HD-高清电视剧、电影在线观看神器 0.025
# 百度网盘 HD 0.025
# 百度网盘 0.025
# 百度糯米-电影,美食团购 0.025
# 百度手机卫士－wifi管家照片管理防骚扰安全助手 0.025
# 百度外卖 -美食订餐品质生活，超市水果安全到家 0.025
# 百度地图HD 0.025
# 百度地图-智能的手机导航，公交地铁出行必备 0.025
# 百度HD-极速安全浏览器 0.025
# 病みカワカメラ 0.025
# 疯狂百宝箱 0.025
# 番茄电玩城 0.025
# 电信营业厅 0.025
# 理财咖(管家版)-金融投资理财产品多样的手机理财工具! 0.025
# 琅琊天下 - 原著改编单机武侠角色扮演RPG 0.025
# 球球大作战 0.025
# 現金製造ロボ -毎日コツコツ3万円稼ぐ- 0.025
# 王权之战-帝国时代皇室争霸！ 0.025
# 猫眼电影 - 一网打尽好电影 0.025
# 猎魔传奇-塔塔&推塔挂机私服手游 0.025
# 犯人は僕です。～露天風呂編～ 0.025
# 犯人は僕です。－謎解き×探索ノベルゲーム－ 0.025
# 特种部队-跨服竞技TCG军事策略游戏 0.025
# 物理パズル:flower（フラワー） 0.025
# 牛タン牛タン牛タンタン 0.025
# 爱奇艺PPS -《欢乐颂2》电视剧热播 0.025
# 爱奇艺HD -《欢乐颂2》电视剧热播 0.025
# 爱奇艺 - 电视剧电影综艺娱乐视频播放器 0.025
# 爆速！マルチ募集掲示板 for モンスト 0.025
# 爆笑アプリ！人気無料ゲーム kimazui gacha 0.025
# 熱血高校！胴上げ部 0.025
# 熊猫直播HD-最娱乐的直播平台 0.025
# 熊猫直播-王者大神主播带你荣耀开黑 0.025
# 無料ゲーム タッチザナンバー（Touch the numbers）計算の脳トレでパズル！ 0.025
# 無料ゲーム HANABI ON LINE 花火（ハナビ）パズル 0.025
# 無料アプリ暇つぶしゲーム【BOKEMON】〜トボケモンスターを進化させるで〜 0.025
# 無料で音楽や写真・カメラの裏技アプリ for iPhone7 0.025
# 無制限で人気音楽聴き放題！ - Music Bank（ミュージックバンク） 0.025
# 热血超人-二次元卡牌游戏 0.025
# 烈焰王座-称霸魔法帝国的策略游戏 0.025
# 炎上なう -つぶやきSNS風シミュレーションゲーム- 0.025
# 激突!!10円玉ドッカンバトル -最強AIに勝てる？- 0.025
# 激ムズ！和のひとふで書き！online 0.025
# 激ムズ！和のひとふで書き！ 〜頭をつかう脳トレパズルゲーム〜 0.025
# 激ムズ！ねこ階段 0.025
# 激ムズ！ねこじゃんぷ２ 0.025
# 激ムズ！にゃんコプター 0.025
# 激ムズ！お前、脱出できんの？～反射神経アクションゲーム～ 0.025
# 激おこ!! はじめしゃちょー　なんなんですか!? 0.025
# 滴滴出行 0.025
# 淘票票 - 原淘宝电影，选座购票必备 0.025
# 淘宝HD－Taobao for iPad 0.025
# 淘宝 - 随时随地，想淘就淘 0.025
# 浪漫庄园(自由创造你的梦想) 0.025
# 流しそうめんエクストリーム 0.025
# 派派激情版-寂陌陌声人交友神器 0.025
# 洋葱圈—正经人的不正经聊天工具 0.025
# 洋菓子店ローズ ～ほのぼの再建記～ 0.025
# 洋码头—正品保证海外买手带你全球购洋货 0.025
# 泰坦来袭-热血英雄燃爆部落争霸之战 0.025
# 注文の多いブサ猫軒 0.025
# 沪江开心词场-英语、日语、韩语学习助手 0.025
# 汽车之家-提供新车,二手车报价及资讯 0.025
# 永生劫 — 单机回合仙侠RPG 0.025
# 每日红包 0.025
# 殺意の国のアリス -狂気に目覚めた童話の主人公たち- 0.025
# 死亡フラグがたちました！！【ノベルゲーム型あるある謎解きアドベンチャー】 0.025
# 歌手発掘 動画投稿アプリ  カラオケ！sing!  App Star 0.025
# 欢乐斗地主•腾讯 0.025
# 楽天市場 for iPad 0.025
# 楽天カード 0.025
# 極限ドリブル～神の子 edition～ 0.025
# 極寒スライダー 0.025
# 森林舞会-3d画面刺激的娱乐城游戏 0.025
# 棒棒糖-宝宝的世界衣橱 0.025
# 梦幻西游互通版 0.025
# 桃太郎の　はなし　は終わっていない #泣ける昔話ノベルゲーム 0.025
# 格斗学院-社团争霸圣装崛起，热血高校一触即发 0.025
# 机票、火车票、汽车票预定助手 for 铁路12306 0.025
# 机甲无双－燃即正义 殿堂级战斗手游 0.025
# 机で卓球 0.025
# 机でGOLF 0.025
# 最高警戒 0.025
# 最長１週間の献立が簡単に作れるme:new（ミーニュー） 0.025
# 最佳足球经理(非彩票) 0.025
# 更加令人感动的养成游戏「昭和杂货店物语２」 0.025
# 暴风影音-BaoFeng Player 0.025
# 暴打三国志-经典RPG角色扮演动作卡牌策略手游 0.025
# 暇なら話そう！誰でも話せて友達も作れる「KoeTomo」 0.025
# 暇つぶしに人気  脳トレ パズルゲーム　- LINK 0.025
# 時計仕掛けの彼女 /明日なんて来なきゃいいのにね 0.025
# 星之轨迹-好玩的手游角色扮演网游新游戏 0.025
# 易到 - 低价专车,高品质出行 0.025
# 早くトイレに行きたい 0.025
# 日曜劇難99.9 0.025
# 无敌战舰-经典策略海战巅峰对决 0.025
# 无双小师妹-登录送橙将 0.025
# 新浪新闻-阅读最新时事热门头条资讯视频 0.025
# 新大主宰-2016卡牌手游巨作！ 0.025
# 新・血液型テスト 0.025
# 斗鱼--王者大神在直播 0.025
# 斗斗大冒险之我爱斗斗堂-官方正版4v4竞技抛物线手游 0.025
# 斗地主·大全-2017年最受欢迎的精品棋牌游戏合集 0.025
# 教えて!goo 0.025
# 擬人缶～俺のペットが少女になった～ 0.025
# 操作しやすいナンプレ！目に優しい パズルゲーム 800問 0.025
# 携程旅行-酒店、机票、火车票预订助手 0.025
# 搜狗输入法-Sogou Keyboard 0.025
# 搜狐视频HD-欢乐颂2 全网首播 0.025
# 搜狐视频-欢乐颂2 全网首播 0.025
# 搜狐新闻—新闻热点资讯掌上阅读软件 0.025
# 搜房网房天下-新房二手房租房交易平台 0.025
# 捨て猫レスキュー 0.025
# 挖财宝理财-预期年化收益高达12% 0.025
# 指神 0.025
# 拼多多 - 1亿人都在拼的购物App 0.025
# 招商银行信用卡掌上生活 0.025
# 招商银行 0.025
# 抢火车票 for 12306火车票官网 0.025
# 投资乐VIP-白银黄金贵金属理财投资 0.025
# 手机百度 - 百度一下你就得到 0.025
# 手机京东-首次购买可领取188元优惠券 0.025
# 戦艦帝国-200艘の実在戦艦を集めろ (2周年記念&世界2000万DL) 0.025
# 戦え！プリンセスドール 0.025
# 战车世纪·经典FC重装机兵归来 0.025
# 战歌联萌-新英雄登场 惊喜嘉年华 0.025
# 我想有个家 0.025
# 我叫MT3-回合制魔幻世界 大型公会副本开荒 0.025
# 成金電鉄-超ハマる放置系ゲーム 0.025
# 懸賞パズルパクロス２ 0.025
# 懸賞ソリティア-懸賞応募でギフト券が稼げるソリティア！-無料懸賞ゲーム 0.025
# 懸賞ソリティア-ギフト券/ギフトコードGETでお小遣いが稼げる定番ソリティアクロンダイク 0.025
# 懂球帝 - 足球迷必备神器 0.025
# 感動アプリ！無料ゲーム Japanese Gacha 0.025
# 愛しのショコラティエ いけめん恋愛ゲーム・乙女げーむ女性向け人気 0.025
# 意味が分かると怖い話【意味怖】-この怖い話の意味が分かるか… 0.025
# 意味が分かると怖い話-この意味怖を謎解きできるか…【謎解き意味怖】 0.025
# 意味が分かると怖い話-この怖い話の意味分かる？【意味怖】 0.025
# 恵方コンパス！【恵方巻を食べる方角がすぐ探せる！】 0.025
# 恵方コンパス. 0.025
# 恋愛消滅ボタン ~ 無料 泣ける恋愛小説 放置ゲーム ~ 0.025
# 恋愛タップコミュニケーションゲーム 週刊マイメイド 0.025
# 恋愛ゴシップ 女性向け恋愛ゲーム！乙女げーむ 0.025
# 恋する幽霊-カレシ、死んでます。- 0.025
# 性格美男美女診断２ 0.025
# 性教育そうだったのか！世界一まなべる保健体育クイズ(画像付き) 0.025
# 快读免费小说-最热网络小说追书神器全本下载阅读器 0.025
# 快看漫画 0.025
# 心霊たんち機 Plus 0.025
# 心动K歌恋爱季-让我们一起唱歌听歌恋爱吧 0.025
# 心の美男美女診断 0.025
# 心がラクになる後ろ向き名言100選 0.025
# 微软识花 0.025
# 征戦エクスカリバー 0.025
# 彼女の涙が僕を人間にした 0.025
# 彩库宝典-【官方版】 0.025
# 当当-正品秒杀，首单立减5元 0.025
# 当たる占い師【水晶玉子】特別鑑定書≪無料占いあり≫ 0.025
# 弹弹堂S- 巴萨传奇助阵 弹弹堂手游官方版 0.025
# 开挂江湖-Q版武侠挂机 0.025
# 开心消消乐® 0.025
# 广东移动手机营业厅-话费流量一手掌握，专属优惠定期发放 0.025
# 幻獣契約クリプトラクト 0.025
# 年賀状2018｜おしゃれなスマホで写真年賀状2018 0.025
# 平安金管家 — 值得信赖的移动金融生活管家 0.025
# 平安证券 0.025
# 平安好车主-用车助手,安全管家 0.025
# 平安好医生-要健康上平安好医生 0.025
# 平安WiFi-手机必备的万能WiFi上网钥匙 0.025
# 帝国征服者-王者联盟列国纷争 0.025
# 币优铺 0.025
# 工银融e联 0.025
# 山手線走ってみた。 0.025
# 屠龙杀 0.025
# 尚品网 - 全球精品高端时尚购物网站 0.025
# 少年西游记－西游卡牌王者之作 0.025
# 少年勇者团 (Combo Warrior)-日系Q萌即时战斗消除RPG手游 0.025
# 小猿搜题HD-中小学拍照搜题作业帮手 0.025
# 小猿搜题-中小学拍照搜题作业帮手 0.025
# 小牛在线-理财投资神器 0.025
# 小咖秀-全民视频才艺直播社区 0.025
# 封神榜（洪荒西游英杰传奇） 0.025
# 宾果消消消 -赵丽颖代言 0.025
# 家长通-一起作业旗下家长端的同步课堂点读机 0.025
# 家計簿マネーフォワード-自動連携で簡単 人気の家計簿 0.025
# 宝宝树孕育-火爆的备孕怀孕育儿社区 0.025
# 宜搜小说-亿万网友共享高品质阅读离线追更 0.025
# 宜人贷借款 0.025
# 完全犯罪クラブ 0.025
# 完全心理プロファイルX 0.025
# 安居客-二手房、新房、租房的找房助手 0.025
# 学年ビリのギャルが今さら受験してみた 0.025
# 妹型杀器 0.025
# 妙资理财（九周年版)-高收益理财投资平台 0.025
# 妙资理财-福利版（年化14.8%注册送1万体验金） 0.025
# 妙资理财-探索版（安全稳健高收益理财神器  ） 0.025
# 妙健康-健康自测管家 0.025
# 如意夺宝 0.025
# 好车无忧二手车—二手车买卖实体店 0.025
# 好きになったら負け。　完全無料！女性向けイケメン恋愛ゲーム 0.025
# 她社区-只有女生的社区！ 0.025
# 女性向けまとめ読みアプリ - pool（プール）- 0.025
# 女子力たったの５、ゴミずら◇恋愛xイケメン育成+放置げー！無料の育成・恋愛・放置ゲーム～ 0.025
# 女の子の憧れが全てつまったTOKYOリアルコーデアプリ - TOPLOG 0.025
# 女の子のための女子トレンドまとめアプリ-ウーマガジン- 0.025
# 奇跡のメガネ　-恋愛シミュレーションゲーム 0.025
# 央视影音HD-海量央视内容高清直播 0.025
# 央视影音-海量央视内容高清直播 0.025
# 天神决-创新仙侠手游 0.025
# 天猫HD 0.025
# 天猫-购物 0.025
# 天天麻将-有奖励的麻将玩法全集 0.025
# 天天快报 - 最热门的新闻资讯软件 0.025
# 大话问仙 - 与众不同的萌派仙侠回合游戏体验(送神器) 0.025
# 大航海世界（风靡日本航海手游《壮绝大航海》正版授权） 0.025
# 大根にしがみつく女子高生 0.025
# 大挂西游 - 降魔之路官方正版 0.025
# 大富豪 Online 0.025
# 大学生のための時間割 0.025
# 大头儿子天天乐跑-和孩子一起玩的游戏！ 0.025
# 大圣捉妖记 0.025
# 大众点评-发现品质生活 0.025
# 大人の脳トレ！ぴたぽん #頭が良くなる #快感ハメコミパズル 0.025
# 大人の納車ゲーム-四角いアタマを丸くする脳トレパズル 0.025
# 大人の出会いチャット  - 出会い系 アプリ 0.025
# 大人のためのかわいいお買い物アプリSUCRESIA(シュクレシア） 0.025
# 大人には解けない問題 0.025
# 大人がハマる脳トレ！ぷるるん～頭が良くなる一筆書きパズル～ 0.025
# 夢王国と眠れる100人の王子様 0.025
# 多重人格彼女〜僕の彼女は世界で一番可愛くて、そして狂っている〜 0.025
# 多融理财(Pro版)-12%高收益理财投资平台 0.025
# 多盈理财-正规手机投资金融理财产品 0.025
# 壊して！無限ドリルランド 0.025
# 坦克新纪元——经典红警狂热回归 0.025
# 坂本ですが？秘技…フリータイムキラー 0.025
# 地元の掲示板「ジモティー」地元でカンタン！フリマよりもお得！ 0.025
# 土豆（短视频分享平台） 0.025
# 土豆视频HD—高清影视综艺视频播放器 0.025
# 国金宝理财-15%年化收益的金融投资赚钱软件 0.025
# 国美在线 – 新人免费领200元优惠券 0.025
# 四角い頭を丸くする2 0.025
# 喜马拉雅FM（听书社区）电台有声小说相声英语 0.025
# 喔豆-发现世间美味 0.025
# 商品バーコードで賞味期限を通知 Limiter2 (リミッター) 0.025
# 唯品会-欢乐颂2独家电商 同款热卖 0.025
# 唯品会 HD 全球精选，正品特卖 0.025
# 咪咕视频-电视剧综艺直播 0.025
# 咕咚-你的跑步骑行运动社区 0.025
# 和我信 0.025
# 君の目的はボクを殺すこと。 0.025
# 君にはクリアできませんよ 0.025
# 吕布帮帮忙-三国策略卡牌，指间微操轻松畅玩 0.025
# 同花顺-炒股、股票 0.025
# 同程旅游-中国汽车票自助周边游海外跟团订票 0.025
# 同城爱约会-单身男女约会神器 0.025
# 史上最强的大脑4-超级王者(时代永恒小强) 0.025
# 召喚AKUMA/悪魔合体召喚～育成シミュレーションRPGゲーム 0.025
# 口袋苍穹-首日送萧炎，重返斗气大陆 0.025
# 口袋电玩-经典街机游戏真人秀版•玩转全民疯狂欢乐火拼炸诈扎金花送斗牛牛麻将VIP 0.025
# 口袋理财（标准版）-上市公司报喜鸟投资 0.025
# 口袋全明星 0.025
# 友達 恋人探し であい ちゃっと sns -ギャルとも 0.025
# 去哪儿旅行HD-总有你要的低价 0.025
# 去哪儿旅行-预订机票酒店火车票特价旅游自由行 0.025
# 去哪儿攻略—查游记旅游攻略，订机票酒店 0.025
# 单读-我们的黄金时代 0.025
# 单机群侠传-金庸群侠传口袋版 0.025
# 单机三国志2-铜雀台资料片 天天都玩 0.025
# 勘違い探し（俺のこと・・・） 0.025
# 勇士与魔龙 0.025
# 剑客情缘-高爆率高掉落天天疯玩 0.025
# 剑仙传奇·蜀山修仙之独步天下 0.025
# 别动我学姐-校园格斗巅峰之作 0.025
# 创客金融-高收益银行存管投资理财平台 0.025
# 出会うカメ 0.025
# 出会い系無料で遊べるsnsアプリ内緒チャットトーク 0.025
# 出会い系アプリ i-Mail（アイメール） 0.025
# 出会い秘密チャット - 相席 出会い系チャット 0.025
# 出会い無料のチャット掲示板 LINK 0.025
# 出会い応援チャットアプリLIKE YOU 0.025
# 农行掌上银行 0.025
# 冒険ディグディグ（ドット絵ｘ放置ｘ冒険RPG） 0.025
# 内涵段子 - 精选搞笑图片、视频 0.025
# 全民炸金花-首款含电玩城百家乐的棋牌游戏 0.025
# 全民暴力摩托-暴力摩托3d免费真实赛车小游戏 0.025
# 全民打金币——爽快的正版放置手游 0.025
# 全民德州扑克-天天尽享拉斯维加斯之夜 0.025
# 全民夺宝-时尚购潮流商品平台 0.025
# 全民夺宝(官方) 0.025
# 全民坦克联盟—坦克帝国官方正版 0.025
# 全民K歌 0.025
# 全国一斉性格テストDX 0.025
# 全国マルチ掲示板 for モンスト！〜タスカンと運極ができるアプリ〜 0.025
# 兜町アナリストがお伝えする「兜予報」（無料） 0.025
# 僕の魔球打てるの？ 0.025
# 僕の彼女は浮気なんかしない 0.025
# 僕の彼女が誘拐された。 0.025
# 僕の彼女が成仏するまで 0.025
# 僕の妹が死んだ。 0.025
# 健康献立レシピ提案 オーガニック “Ohganic" 0.025
# 倩女幽魂-周年庆资料片开启新主角剧情 0.025
# 借金勇者~そして完済へ… 0.025
# 借金あるからギャンブルしてくる 0.025
# 借贷宝-直投熟人更高明 0.025
# 俺と鬼嫁の100日戦記 0.025
# 俺が浮気した時の話、聞く？ 男女の修羅場の話まとめ 0.025
# 修仙侠侣-正统中国风仙侠新作 0.025
# 信用钱包官方版-用手机号就能贷款 0.025
# 你我贷理财-基金理财工具 0.025
# 你我贷理财-P2P理财管家 0.025
# 作业通-中小学搜题搜作文必备神器 0.025
# 作业帮-小初高学生拍照答疑学习辅导助手 0.025
# 传说一刀 - 一刀一级PK爆屠龙 0.025
# 伙星 - 随手拍出明星一样的MV 0.025
# 优酷视频 0.025
# 优信二手车-二手车买车卖车评估交易平台 0.025
# 企业微信 0.025
# 任务客 0.025
# 仙侠剑客—大型3D精品ARPG动作神作 0.025
# 今日头条 - 热点新闻资讯、娱乐视频 0.025
# 今日、彼女が死んだ 0.025
# 人気の動画まとめてみた。"for YouTube" 0.025
# 人众金服[回馈版]-高收益理财软件 0.025
# 京东金融-【618周年庆】新人领千元好礼 0.025
# 京东 HD 0.025
# 交通银行信用卡买单吧 0.025
# 五目並べ - オンライン対戦搭載！ 0.025
# 二炮手-同名抗战狙击手游(孙红雷主演) 0.025
# 乐视视频HD-白鹿原,欢乐颂,奔跑吧全网热播 0.025
# 乐视视频-白鹿原,欢乐颂,奔跑吧全网热播 0.025
# 乐视体育—英超欧冠F1高清直播 0.025
# 乐享动-有运动音乐推荐的计步器 0.025
# 主播炸金花 0.025
# 丸亀製麺 0.025
# 中国银行手机银行 0.025
# 中国联通手机营业厅客户端(官方版) 0.025
# 中国移动手机营业厅(中国移动官方) 0.025
# 中国搜索-国家权威搜索 0.025
# 中国建设银行 0.025
# 中国工商银行 0.025
# 中华万年历-2亿用户首选的日历软件 0.025
# 东西战神 0.025
# 东方头条（探索版）订阅分享感兴趣的新闻和搞笑视频 0.025
# 世界邦行程大师-出国自由行定制专家 0.025
# 不良西游-神魔悟空大战篇 0.025
# 不思議雑貨店ローズ ～ほのぼの再建記～ 0.025
# 下ヨシ子の「２０１６年　あなたの流生命」 0.025
# 上海移动掌上营业厅 0.025
# 上司と秘密の2LDK　Love Happening 0.025
# 三国杀传奇-神将觉醒 0.025
# 万年历-日历农历黄历天气 0.025
# 万年历-农历黄历日历天气 0.025
# 万年历-值得信赖的日历黄历查询工具 0.025
# 一骑当千OL-万人国战（Legend Of Warrior） 0.025
# 一起捕鱼 - 欢乐街机电玩城 0.025
# 一起作业学生端-中小学霸口袋学习辅导助手 0.025
# 一筆書きゲーム！無料パズルで脳トレしよう！ by だーぱん 0.025
# ワンダークラウン 0.025
# ロボはつらいよ。～フルボッコタワー～アクション育成強化ゲーム！ 0.025
# レアジョブ瞬間中学英単語 | リスニングやTOEICの基礎学力にも 0.025
# リア充撲滅RUN 0.025
# ライブチャット、ビデオチャット通話が楽しめる！ ライブでゴーゴー 0.025
# ヨドバシ 0.025
# ヤフオク! 利用者数NO.1のオークション、フリマアプリ 0.025
# モン娘は～れむ【モンはれ】 0.025
# モンスト覇者の塔マルチ掲示板 for モンスターストライク 0.025
# モンスト全国マルチ掲示板 for モンスターストライク！〜タスカンと運極が作れるアプリ〜 0.025
# モンストマルチ掲示板 〜 The BEST 〜 for モンスターストライク 0.025
# モンスト マルチ掲示板 運極 ＆ ガチャ予報 & 攻略情報 for モンスターストライク 0.025
# モンスターマスターX【オンライン対戦型RPG（ロールプレイング・ゲーム）】 0.025
# マンガ図書館Z -人気漫画が読み放題！ 0.025
# マンガモンスター 　無料マンガ/無料本/人気マンガ 0.025
# マンガきゅんと‐漫画が全話読み放題の少女まんがアプリ 0.025
# ママはストーカー 0.025
# マッチングならSecret- 友達・恋人探しSNS 0.025
# マッチング チャット - マッチング&恋人探しチャット 0.025
# マジ死にゲー 0.025
# マクドナルド - McDonald's Japan 0.025
# マイにゃんカフェ 0.025
# ポケ電バッテリー for ポケモンGO 0.025
# ホラースポット-ghost spot-意味が分かると怖いマップ 0.025
# ホットペッパービューティー/サロン予約 0.025
# ホストのアブナイ世界 0.025
# プリンセスクローゼット 女性向け恋愛ゲーム！乙女げーむ 0.025
# ブリ猫 0.025
# ブラックバイトはじめました。２　～居酒屋編～ 0.025
# ブラックバイトはじめました。俺の嫁に捧げるストーリー【放置】 0.025
# フリル(FRIL) - 満足度No.1 のフリマアプリ 0.025
# フラッシュワード〜光速瞬間記憶脳トレクイズ〜 0.025
# ファンタジードライブ【快進撃3DRPG】 0.025
# ファッション通販 ZOZOTOWN 0.025
# ピンポンファイター - 卓球王にオレはなるっ！！ 0.025
# ピンポンカーブ  君の反射神経Lvはいくつ？  #天才求ム 0.025
# ピッタリあわせて！脳トレcube 0.025
# ピタゴラパブロフ 0.025
# ピグパーティ - きせかえ・アバターで楽しむトークアプリ 0.025
# ビルホッピング 0.025
# ビッグバン チャット-友達作り ひま友チャット 0.025
# バーチャル高校野球 0.025
# バーチャル恵方巻【節分・恵方コンパス・方位】 0.025
# ハマる脳とれ ぱずる!!PITTARI～子供も楽しめる脳とれ ぱずるげーむ～ 0.025
# ハニーズアプリ 0.025
# ニート勇者３ -闇の側の者たち- 無料ロールプレイングゲームRPG 0.025
# ニュース速報と災害地震速報が届くライフライン NewsDigest（ニュースダイジェスト） 0.025
# ニュースパス -かんたん操作で必要なニュースがすぐ読めるニュースアプリ 0.025
# ナビタイムの乗り換え案内 - 遅延情報やバス時刻表を案内するアプリ 0.025
# ナビタイム ドライブサポーター - NAVITIMEのカーナビアプリ 0.025
# ナニワ金融道　全巻無料のマンガアプリ 0.025
# ナイトメアハーレム 女性向け恋愛ゲーム！乙女げーむ 0.025
# ドリブルの達人 0.025
# トリセツメーカー２　トリセツ診断 0.025
# トリセツメーカー　トリセツ診断 0.025
# トクバイ - チラシアプリ／スーパーの特売情報で節約 - 0.025
# デジラアプリ - データ容量のやりくりに 0.025
# ディグラム恋愛診断 0.025
# テレビ視聴 0.025
# テトリマン 0.025
# ダニエル！！今はフリーキック中よ！ 0.025
# ダウト～嘘つきオトコは誰？～ 0.025
# ダイエット女子が痩せた魔法のアプリ-食事・運動・美容＠DIET 0.025
# ダイエットやメイク、ネイルのコスメ情報 - シェリル 0.025
# ダイエットが続く！人気のカロリー・体重管理アプリ 「もぐたん」 0.025
# タップル誕生 - 出会いアプリで趣味から恋活・婚活 0.025
# タップモンスター◆タップだけの簡単本格RPG/タプモン 0.025
# センバツLIVE!2017／第89回選抜高校野球大会公式アプリ 0.025
# セブン‐イレブンアプリ 0.025
# スロットマニア・フィーバー～本場ラスベガススロット 0.025
# スマイルパーク 〜らくらく放置系遊園地ゲーム〜 0.025
# スピードOnline トランプゲーム 0.025
# スッキリ謎解きゲーム！！ 0.025
# スタンバイ 仕事もバイトも暮らしにあった選び方 0.025
# スタバで呪文 0.025
# スシロー 0.025
# スカッと！脳トレ！ピッといん〜頭がよくなるブロックパズルゲーム〜 0.025
# ジーユー 0.025
# ジョナサンアプリ　お得なクーポンが使える便利なアプリ 0.025
# ジェスチャー当て 0.025
# シルエットクイズ～人気マンガ・映画アニメキャラ・芸能人で暇つぶし脳トレ 0.025
# シュッと描いてポンッ!（シュポン）物理パズル脳トレ 0.025
# シカクイズ -暇つぶしマンガアニメ映画クイズ-暇つぶしに最適 0.025
# サッカーカーニバル 0.025
# サクッとスッキリ！ラインナンバー！ 0.025
# サクサクチェッカー 最適化  -  iChecker 0.025
# ゴールできたら神！！2 0.025
# ゴミカレ!! 0.025
# ゲーム攻略「SGGP」掲示板、SNSな友達出会い 0.025
# ゲームプレイで賞金ゲット！ポットハンター 0.025
# ゲッターズ飯田の占い 0.025
# ゲスの極み!パリピを探せ!!笑える・ハマる間違い探しゲーム（意外と難問） 0.025
# ゲオ　クーポンが貰える！ゲーム予約もできる！ 0.025
# ケンタッキーフライドチキン　公式アプリ 0.025
# グルータ / 最新ニュースまとめをグループチャットで！(Grouta) 0.025
# クリスマスミッケ/脱出ゲーム感覚の絵探しパズルゲーム 0.025
# クリアしてみろよ？ 神ゲー アクション ゲーム 0.025
# クリアした奴マジ天才 0.025
# クックパッド - No.1料理レシピ検索アプリ 0.025
# キンニクエスト 筋肉と筋肉と筋肉と呪われし筋肉 0.025
# キモゲーいや、きも毛ー 0.025
# キスまでにしたい10のこと ~ 無料 胸きゅん恋愛小説 放置げーむ ~ 0.025
# ガールズちゃんねる - 女子のニュースとガールズトーク 0.025
# カテエネ×Shufoo！ 0.025
# オーブGETマルチ掲示板！ for モンスト 0.025
# オトナの教科書〜学校じゃ教わらない裏教育クイズ(画像付き)〜 0.025
# オオカミ姫 [ みんなで協力！ターン制ギルドバトルRPG ] 0.025
# エレメンタル ファンタジー - 高精細３ＤアクションＲＰＧ 0.025
# エジコイ！〜エジプト神と恋しよっ〜 0.025
# イケメン革命◆アリスと恋の魔法 恋愛ゲーム 0.025
# アキラメロン【メロンを受け止める、チョイムズゲー】 0.025
# アウト～まさか浮気してないよね？～【恋愛不倫探しゲーム】 0.025
# アイドルの姫　-わたしの青春マテリアル- 0.025
# らぶいずふぉーえばー #泣けるピアノゲーム 0.025
# ようとん場 0.025
# ゆるドラシル -本格派神話RPG- 0.025
# やる夫のチャリ 0.025
# もやししゃちょー 0.025
# もじさがし 0.025
# もこうもこもこ 0.025
# みんなの性格検定 0.025
# みんなのお弁当 by クックパッド ~お弁当をレシピ付きで記録・共有~ 0.025
# まるみえ！性教育ふしぎ発見-クイズで学ぶ保健体育 0.025
# まっぷるリンク - 旅行ガイドを丸ごとアプリで持ち歩き 0.025
# まぐろ職人（通） 0.025
# まぐろ投げ！ 0.025
# ぼっちでもリア充になれる奇跡のアプリ。〜恋する缶づめ。〜 0.025
# ぼくのボッタクリBAR2 -全国制覇篇- 0.025
# ほぼ無理ゲー 0.025
# へびでか〜へび刑事純情物語〜【放置ゲーム】 0.025
# ぷちドラシル 〜ゆるドラ外伝〜 0.025
# ぷかぷか 0.025
# ひみつの出会い探しはバクアイ-無料の出会いチャットアプリで友達作り 0.025
# ひとりぼっち惑星 0.025
# ひとほろぼし 0.025
# ひとたがやし 0.025
# ぱちモンパズル〜簡単無料パズルRPGゲーム 0.025
# はじめん　～はじめとつくる動画生活～ 0.025
# のび毛 0.025
# ねこめし屋 -マンガも読めるネコゲーム料理店経営の無料育成シュミレーション- 0.025
# ねこみっけ - おもしろい人気無料ゲーム 0.025
# ねことダンボール 0.025
# ねこげーむ~ねこ騎士ポチ~簡単で人気の猫ゲーム~基本無料 0.025
# ねこあわせ。 0.025
# にゃんちゅう 0.025
# なっとう-人気の納豆育成ゲーム- 0.025
# なぞって冒険！きゅるるんくまのパズルリンク 0.025
# どうして私じゃダメなの？ 0.025
# それゆけ！ヤンキッキー 0.025
# そら案内 0.025
# さすゆう -さすがは勇者様です-無料放置系お手軽RPG!! 0.025
# これやったことない人いる？ 0.025
# こっち見んなwww 0.025
# こち亀 公式連載アプリ〜こち亀の漫画が読めるアプリ〜 0.025
# ここに墓を建てよう 0.025
# がんばれルルロロ！かさねてブロック 0.025
# お解きなさい！ 0.025
# お小遣いアプリ。ポイントをレシートで貯めよう　／　レシポ！ 0.025
# お前は俺の女だろーが【胸キュン恋愛、リア充ストーリー！？】 0.025
# おチャベリ-ビデオ通話でマッチングアプリ 0.025
# おわかりいただけただろうか心霊写真で最恐ホラー体験 0.025
# おやじが跳ぶ 0.025
# おそ松さんのへそくりウォーズ　〜ニートの攻防〜 0.025
# おじクエ - OJISAN QUEST - タップRPG - 0.025
# おかんからのメッセ - ほのぼの謎解きゲーム 0.025
# おかず甲子園 0.025
# えほう - 最強の恵方コンパス 0.025
# うねうね糸 0.025
# 【難問謎解き】ねこ神様はクイズ好き？ 0.025
# 【負けるが勝ち？】少数派に入れば勝利の7Beget 0.025
# 【謎解き推理】意味が分かると怖い話-この怖い話を謎解き、怪談を読み解けるか… 0.025
# 【謎解き】自称カノジョからの病みすぎメッセージ 0.025
# 【謎解き】罪と罰-ノベルゲーム型 推理アドベンチャー 0.025
# 【謎解き】ヤミすぎ彼女からのメッセージ 0.025
# 【脳トレ】ROLL -ころがす、はめる、きえる- 0.025
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜 0.025
# 【真・お絵かきパズル】〇〇投げてみた結果ｗｗ　完全無料！ 0.025
# 【殺人現場へようこそ】推理サスペンス劇場/謎解き大人の脳トレゲーム 0.025
# 【業界初成長マップ搭載！ねこ育成マト当てパズルRPG】たまねこウォーズ 0.025
# 【放置ゲー】壁ドンしたら人生変わった ～グリモアのキャラ達に壁ドン！？～ 0.025
# 【放置】勇者改名 ～「ふざけた名前つけやがって！」 0.025
# 【推理ゲーム】 YASU-第7捜査課事件ファイル- 0.025
# 【意味笑】意味が分かると面白い話-謎解き2ch系推理ゲーム 0.025
# 【悲報】鬼ヶ島終了のお知らせ　-ゾンビ桃太郎が3Dすぎて鬼やばいwww- 0.025
# 【実況】今からカレシを葬る #衝撃の実況動画ノベルゲーム 0.025
# 【完全無料】ソク出会える！ひみつフレ探し掲示板 0.025
# 【完全無料】おとな専用！出会い掲示板 0.025
# 【マイナビバイト大学生版】大学生のバイト探し・アルバイト求人 0.025
# 【ドレ？ドコ？】脱出ゲーム感覚の謎解きパズルゲーム 0.025
# 【カノピッピ大作戦】ギャルがオタクに恋をした/脱ギャル系彼女育成ゲーム 0.025
# 【よく当たる】手相鑑定〜選べる鑑定ジャンル(人生運、仕事運、恋愛運) 0.025
# 【ひっぱりパズル】ズキュ〜〜〜〜ン！ 0.025
# 【はらぺこパズル】ごはんに恋をした 0.025
# 【2017年の運勢決定版】ゲッターズ飯田の占い 0.025
# 「おつぼね」“あるある”エンターテイメントストーリー：OTUBO（お局） 0.025
# 《女性口コミNo.1》水晶玉子の幸福領域占い 0.025
# ▻Sudoku 0.025
# ▻Solitaire 0.025
# ■ Square it! 0.025
# ⋆Solitaire⋆ 0.025
# ⋆Solitaire 0.025
# ∞ Infinity Loop 0.025
# wetter.com 0.025
# vente-privee 0.025
# theSkimm 0.025
# the SOUL of SEVENS【ソウル オブ セブンス】 0.025
# striker – dropping balls 0.025
# splix.io! 0.025
# slither.io 0.025
# skyticket - Reserve Best Valued Air Tickets 0.025
# shopkick - Shopping Rewards & Discounts 0.025
# same - 就是聊得来 0.025
# real happy majiang-all stars majiang,mahjong 0.025
# radio.de - Der Radioplayer 0.025
# pixivコミック - みんなのマンガアプリ 0.025
# ooVoo – Free Video Call, Text and Voice 0.025
# niconico ch 0.025
# niconico 0.025
# n-tv Nachrichten 0.025
# myChevrolet 0.025
# myCANAL - la TV by CANAL en direct et replay 0.025
# myAT&T 0.025
# my KONAMI Slots - Vegas Casino Slot Machine Games 0.025
# musical.ly - your video social network 0.025
# minne - shopping handmade item 0.025
# minimo（ミニモ）/サロン予約 0.025
# mememo(ミーメモ)ダイエット〜生理日予測まで女性サポート 0.025
# lollicam - photo, video, and selfie camera 0.025
# live.ly - live video streaming 0.025
# letgo: Buy & Sell Second Hand Stuff 0.025
# kurashiru [クラシル] - 料理レシピ動画数No.1 0.025
# js体育资讯 0.025
# ipsy - Makeup, subscription and beauty tips 0.025
# intoLive - Custom Live Photos wallpaper maker 0.025
# in-capturing moments in life 0.025
# imo video calls and chat 0.025
# ikouhoushi 0.025
# ibis Paint X - speed painting 0.025
# iWeather - World weather forecast 0.025
# iTunes U 0.025
# iTranslate - Language Translator & Dictionary 0.025
# iSwap Faces LITE 0.025
# iSleeping by iSommeil SARL 0.025
# iSlash Heroes 0.025
# iPlum Business Phone Number for Calling & Texting 0.025
# iPaint uPaint 0.025
# iHeartRadio – Free Music & Radio Stations 0.025
# iGun Pro HD - The Original Gun Application 0.025
# iFunny :) 0.025
# iExit Interstate Exit Guide 0.025
# happn — Dating app — Find and meet your crush 0.025
# gogogo 0.025
# go90 – Stream TV & Live Sports 0.025
# francetv JO – Regarder les Jeux Olympiques de Rio 2016 0.025
# franceinfo - l'actualité & les élections en direct 0.025
# flick（フリック）- みんなの顔文字キーボードから名前が変わりました 0.025
# e袋洗-新用户领20元优惠券，20分钟上门取送 0.025
# edjing Mix:DJ turntable to remix and scratch music 0.025
# eHarmony™ Dating App - Meet Singles 0.025
# eBay: Best App to Buy, Sell, Save! Online Shopping 0.025
# eBay Kleinanzeigen - Free. Easy. Local. 0.025
# diep.io 0.025
# cute icon&wallpaper dressup - CocoPPa 0.025
# comico/人気オリジナル漫画が毎日更新！/コミコ 0.025
# codeSpark Academy with The Foos - coding for kids 0.025
# camera for filter 0.025
# caRRage 0.025
# botman - Real time video chat 0.025
# boohoo.com 0.025
# bit-tube - Live Stream Video Chat 0.025
# ameli, l'Assurance Maladie 0.025
# airweave sleep analysis 0.025
# adidas Confirmed 0.025
# aa 0.025
# a. - Physical Simulation Puzzle Game 0.025
# [GP]パチスロ ヱヴァンゲリヲン〜決意の刻〜(パチスロゲーム) 0.025
# [GP]パチスロ デビル メイ クライ クロス(パチスロゲーム) 0.025
# [GP]ハナハナホウオウ-30(パチスロゲーム) 0.025
# [GP]アナザーゴッドハーデス-奪われたZEUSver.-(パチスロゲーム) 0.025
# [GP]SLOT魔法少女まどかマギカ(パチスロゲーム) 0.025
# Zootopia Crime Files: Hidden Object 0.025
# Zoopla Property Search -UK Homes for Sale and Rent 0.025
# Zombies Chasing Me 0.025
# Zombie Tsunami 0.025
# Zombie Town Story 0.025
# Zombie Highway 2 0.025
# Zombie Frontier 3 – Top Zombie Shooting Game 0.025
# Zombie Catchers 0.025
# Zombie Castaways 0.025
# Zombie Anarchy: Survival Strategy Game 0.025
# Zillow Real Estate - Homes for Sale & for Rent 0.025
# ZigZag 0.025
# Zig Zag Boom 0.025
# Zenly - Locate your friends in realtime 0.025
# ZenDots 2 - One Dot’s Journey 0.025
# Zen Pinball 0.025
# Zen 0.025
# Zappos: shop shoes & clothes, fast free shipping 0.025
# Zap Zombies 0.025
# Zaim 0.025
# ZaZa Remote-Universal Remote Control 0.025
# ZEDGE™ Wallpapers 0.025
# ZEDGE™ Ringtones 0.025
# ZDFmediathek 0.025
# ZARA 0.025
# ZAGA 0.025
# Z Buster 0.025
# Yurekuru Call 0.025
# Yurei Ninja 0.025
# Yup - Homework Help with Math & Science Tutors 0.025
# Yummy Birthday - Party Food Maker 0.025
# Yu-Gi-Oh! Duel Links 0.025
# You勇者 -HIKAKINとSEIKIN(ヒカキンとセイキン)と無料ロールプレイング 0.025
# Youmiam 0.025
# Youku HD 0.025
# YouTurbo 0.025
# YouTube Music 0.025
# YouTube Kids 0.025
# YouTube - Watch Videos, Music, and Live Streams 0.025
# YouNow: Live Stream Video Chat 0.025
# YouCam Perfect - Photo & Selfie Editor 0.025
# YouCam Makeup: Magic Makeup Selfie Cam 0.025
# YouCam Fun - Live Selfie Video Filters 0.025
# You hate me? わたしのこと きらい？ 0.025
# You Stupid 0.025
# You Doodle - draw on photos & pictures, add text 0.025
# Yoshirt - Design Your Own Custom Tshirt, Tote Bag, Socks and More 0.025
# Yelp - Nearby Restaurants, Shopping & Services 0.025
# Yellow - Make new friends 0.025
# Yahoo!防災速報 - 地震や豪雨など災害情報をいち早く通知 0.025
# Yahoo Weather 0.025
# Yahoo Sports - Teams, Scores, News & Highlights 0.025
# Yahoo Mail - Keeps You Organized! 0.025
# Yahoo Fantasy Sports 0.025
# YY- 小全民手机直播交友软件 0.025
# YY HD-和美女帅哥主播视频聊天的直播软件 0.025
# YO-KAI WATCH Wibble Wobble 0.025
# YAZIO – Calorie Counter & Nutrition Tracker 0.025
# YAHTZEE® With Buddies: The Classic Dice Game 0.025
# Xmas Swipe - Christmas Match 3 Puzzle 0.025
# Xbox 0.025
# XFINITY Stream 0.025
# X-War: Clash of Zombies 0.025
# Wrassling 0.025
# Would You Rather? 0.025
# Worm.is: The Game 0.025
# World of Tanks Blitz 0.025
# World of Cubes Survival Craft 0.025
# World Spin - Create & Play 0.025
# World Craft HD 0.025
# World Craft - Epic Dream Island 0.025
# World Chef: Restaurant & Cooking Game 0.025
# Workflow: Powerful Automation Made Simple 0.025
# Words with Friends – Best Word Game 0.025
# Words Crush: Hidden Words! 0.025
# Wordalot – Picture Crossword 0.025
# WordWhizzle Search 0.025
# WordWhizzle 0.025
# WordNerd - The picture puzzle game for word nerds 0.025
# WordBubbles! 0.025
# WordBrain 2 0.025
# WordBrain 0.025
# Word Trek  - WordTrek Brain game & Word puzzles 0.025
# Word Search Colorful 0.025
# Word Flow Keyboard - GIF, swipe, custom theme 0.025
# Word Cookies! 0.025
# Wooden Block Puzzle - Wood jigsaw fit 1010 matrix 0.025
# Wonderball - One Touch Endless Ball Arcade Action 0.025
# Wonder Tactics 0.025
# Wonder Keyboard: Sound Smart & Funny with AI 0.025
# WoW Legion Companion 0.025
# Wizard of OZ: Magic Match 0.025
# Wizard Swipe 0.025
# Within - VR (Virtual Reality) 0.025
# Wishbone - Compare Anything 0.025
# Wish - Shopping Made Fun 0.025
# Wire de Coins 2 0.025
# Wire Bounce 0.025
# Winterstate 0.025
# Winter Fugitives 2: Chronicles 0.025
# Win the White House 0.025
# Willy Wonka Slots: Vegas Casino Slot Machines 0.025
# Wild City Rush - Urban Jungle Adventure 0.025
# WiFi钥匙—万能wifi密码钥匙 0.025
# Wi-Fiミレル 0.025
# Why You Lying? 0.025
# Whole Foods Market 0.025
# White Tiles 4: Piano Master (All mini games in 1) 0.025
# White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game 0.025
# Whisper - Share, Express, Meet 0.025
# Where's My What? Free 0.025
# Where's My Water? 2 0.025
# Where is Santa Lite - Santa Tracker 0.025
# WhenToPost: Best Time to Post Photos for Instagram 0.025
# When you clear one,million yen CHANCE!! 0.025
# Wheel of Fortune: Game Show Word Puzzles 0.025
# Wheel of Fortune Slots Casino with Vanna White 0.025
# WhatsApp Messenger 0.025
# Whataburger 0.025
# What Jump - Free Pop Arcade Game 0.025
# What Dog A Microsoft Garage Project 0.025
# Werewolf "Nightmare in Prison" 0.025
# Wells Fargo for iPad 0.025
# Wells Fargo Mobile 0.025
# Wellbeyond Meditation for Kids 0.025
# Welcome to Virtual Reality 0.025
# Weirdwood Manor 0.025
# Weight Watchers 0.025
# Weibo HD 0.025
# Weibo 0.025
# Weed Firm: RePlanted 0.025
# Weed Firm 2: Back To College 0.025
# Wedding Planner - Dress Up, Makeup & Cake Design 0.025
# Webcams – EarthCam 0.025
# Webcams Viewer - Live Video Surveillance IP Cams 0.025
# WebMD for iPad 0.025
# WeatherBug - Local Weather, Radar, Maps, Alerts 0.025
# Weather Underground: Custom Forecast & Local Radar 0.025
# Weather Live Free - Weather Forecast & Alerts 0.025
# Weather - Radar - Storm with Morecast App 0.025
# Weather & Radar 0.025
# WeChat 0.025
# We Heart It - Fashion, wallpapers, quotes, tattoos 0.025
# Waze - GPS Navigation, Maps & Real-time Traffic 0.025
# Wayfair - Shop Furniture, Home Decor, Daily Sales 0.025
# Wave 0.025
# Waterlogged - Daily Hydration Tracker 0.025
# Water Bottle Flip Challenge: Flippy Bottle Diving 0.025
# Water Bottle Flip Challenge : Endless Diving 2K16 0.025
# Water Bottle Flip Challenge : 2k16 0.025
# Water Bottle Flip Challenge 2 0.025
# Water Bottle Flip Challenge - 2k16 Pro! 0.025
# Water Bottle Flip Challenge 0.025
# Water Bottle Flip AK 2016 0.025
# WatchESPN 0.025
# Watch TNT 0.025
# Watch TBS 0.025
# Watch OWN 0.025
# Watch NFL Network 0.025
# Warriors of Glory 0.025
# Warrior Balls 0.025
# Warp Shift 0.025
# WarnWetter 0.025
# Warlords - Turn Based Strategy 0.025
# Warhammer 40,000: Freeblade 0.025
# Warcher Defenders 0.025
# War of Warship:Pacific War 0.025
# War Tortoise 0.025
# War Robots 0.025
# War Machines: 3D Multiplayer Tank Shooting Game 0.025
# War Dragons 0.025
# War Commander: Rogue Assault 0.025
# Wappoi Room Escape 0.025
# Walmart: Free 2-Day Shipping,* Easy Store Shopping 0.025
# Walls & Balls 0.025
# Wallpapers for Me - Themes & Background Images 0.025
# Wall Switch 0.025
# Walking for Weight Loss: training plans, GPS, tips 0.025
# Walk for a Dog 0.025
# Walgreens – Pharmacy, Photo, Coupons and Shopping 0.025
# Waiit 0.025
# WWF Together 0.025
# WWE SuperCard 0.025
# WWE Immortals 0.025
# WWE 0.025
# WWDC 0.025
# WSVN Hurricane Tracker 0.025
# WRAL Weather Alert 0.025
# WKC Dog Show 2017 0.025
# WIRED Magazine 0.025
# WIND runner adventure 0.025
# WGT Golf Game by Topgolf 0.025
# WEB.DE Mail 0.025
# WEAR - Fashion Lookbook 0.025
# VyStar Mobile Banking for iPhone 0.025
# VyStar Mobile Banking for iPad 0.025
# Vudu - Movies & TV 0.025
# Voyages-sncf.com : book train and bus tickets 0.025
# VoiceTra(Voice Translator) 0.025
# Voice Recorder (FREE) 0.025
# Voice Changer Plus 0.025
# Vlogger Go Viral - Clicker Game & Vlog Simulator 0.025
# Viva™ Slots Las Vegas Classic Casino Games 0.025
# VivaVideo - Best Video Editor & Photo Movie Maker 0.025
# Visage makeup editor plus photo teeth whitener 0.025
# Virtual Regatta Offshore 0.025
# Virtual Reality Roller Coaster for Google Cardboard VR 0.025
# Virtual Reality Moon for Google Cardboard VR 0.025
# Virry Educational. Play, learn with real animals 0.025
# Virginia Tech Emoji 0.025
# Vintage Slots Las Vegas - Old Slot Machine Games! 0.025
# Vine Camera 0.025
# Village Life: Love, Marriage and Babies 0.025
# Vikings: War of Clans 0.025
# Video speed editor - VBooster 0.025
# Video Smith - A Powerful video editing tool set 0.025
# Video Call Santa Claus Christmas - Catch Kids Wish 0.025
# Video & TV Cast for Chromecast: Best Browser to cast and stream webvideos and local videos on TV & Displays 0.025
# Victoria’s Secret – The Sexiest Bras & Lingerie 0.025
# Vice Lipstick 0.025
# Viber Messenger – Text & Call 0.025
# Viator Tours & Activities 0.025
# ViRATES[バイレーツ]-面白ネタまとめの決定版！ 0.025
# Vestiaire Collective - Pre-Owned Luxury Fashion 0.025
# Versus Run 0.025
# Versus - Multiplayer Game (2 players) 0.025
# Verizon Cloud 0.025
# Venmo 0.025
# Vendée Globe 2016 0.025
# Vehicles & Weapons Mods for Minecraft PC Edition - Best Pocket Wiki & Tools for MCPC 0.025
# VeeR VR - Virtual Reality 0.025
# Vector 2 0.025
# Vault! 0.025
# Valley of Fear Virtual Reality 0.025
# Vainglory 0.025
# VSCO 0.025
# VS. Racing 2 0.025
# VR-Crazy Car Traffic Racing 0.025
# VR Water Park:Water Stunt & Ride For VirtualGlasse 0.025
# VR Video World - Virtual Reality 0.025
# VR Tube - Virtual Reality 360 Video Player 0.025
# VR Thrills: Roller Coaster 360 (Google Cardboard) 0.025
# VR Street Jump for Google Cardboard 0.025
# VR SNIPER 0.025
# VR Roller-Coaster 0.025
# VR Roller Coaster for Google Cardboard 0.025
# VR Roller Coaster World - Virtual Reality 0.025
# VR Horror Maze Walk :Horror Fever For VR Cardboard 0.025
# VR Haunted House 3D 0.025
# VR HORROR 0.025
# VR Flight Simulator for Google Cardboard 0.025
# VR Death Simulator 0.025
# VR Crazy Bike Race: Traffic Racing Free 0.025
# VR Car Driving Simulator for Google Cardboard 0.025
# VR Ball for Google Cardboard Virtual Reality 0.025
# VPN SecureLine - privacy & security by Avast 0.025
# VPN Proxy Master - Unlimited WiFi security VPN 0.025
# VPN Go - Safe Fast & Stable VPN Proxy 0.025
# VPN Express 0.025
# VOEZ 0.025
# VIZIO SmartCast™ - Cast & Control Movies & TV Show 0.025
# VIDO - Rewards, Music and Videos for YouTube 0.025
# VIBO RealMassager 0.025
# V LIVE - Broadcasting App 0.025
# Urlaubspiraten 0.025
# Upperland 0.025
# Univision NOW – Stream TV en Vivo y On Demand 0.025
# Univision Deportes: Liga MX, MLS, Fútbol En Vivo 0.025
# United Airlines 0.025
# Unison League 0.025
# Uncolored Boy 0.025
# Ultimate Briefcase 0.025
# Ulterior 0.025
# Ugly 0.025
# Uber优步中国 0.025
# UberEATS: Uber for Food Delivery 0.025
# Uber Driver 0.025
# Uber 0.025
# USAA Mobile 0.025
# USA TODAY 0.025
# US Presidential Election 2016 - Polls 0.025
# UNiDAYS: Student Discounts for Shopping Top Brands 0.025
# UNO ™ & Friends 0.025
# UNKILLED: MULTIPLAYER ZOMBIE SURVIVAL SHOOTER GAME 0.025
# UNCHARTED: Fortune Hunter™ 0.025
# UFC ® 0.025
# UE BOOM 0.025
# UDONちゅるん 0.025
# UC浏览器HD 0.025
# UA Shop by Under Armour 0.025
# U by BB&T 0.025
# U Compass ( North, South, East and West ) 0.025
# Tynker - Learn to Code. Programming Made Easy. 0.025
# Two Dots 0.025
# Twitter 0.025
# Twitch 0.025
# TwitCasting Viewer - Watch Live Video & Radio 0.025
# Twisty Wheel 0.025
# Twisty Board 0.025
# Twisty Arrow - Shoot the Circle Wheel 0.025
# Twist 0.025
# TwinSpires Official Kentucky Derby Wagering App 0.025
# Twin Shooter - Invaders 0.025
# Twin Moons Society™: Hidden Mystery 0.025
# TurboTax Tax Return App - File 2016 income taxes 0.025
# Turbo Dismount® 0.025
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music 0.025
# Tumblr 0.025
# Tubi TV - Watch Free Movies & TV Shows 0.025
# Tubex - Videos and Music for YouTube 0.025
# Truth or Dare · 0.025
# Truth Or Dare — Party Game 0.025
# Trump On The Run 0.025
# Trump Hoverboard Sim - Mannequin Race Challenge 0.025
# Trump Dump ⁢ 0.025
# Trump Bounce 0.025
# Truecaller - Spam Identification & Block 0.025
# Trucker Parking Simulator 2 a Real Monster Truck & Lorry Driving Test 0.025
# Tropical Wars - Pirate Battles 0.025
# Tropical Twist 0.025
# Trolls: Crazy Party Forest! 0.025
# Troll Face Quest Video Memes 0.025
# Troll Face Quest Video Games 0.025
# Trivia Crack Kingdoms 0.025
# Trivia Crack 0.025
# TripAdvisor Hotels Flights Restaurants 0.025
# Trio 0.025
# Triller - Music Video & Film Maker 0.025
# Trigger Fist 0.025
# Triennale Game Collection 0.025
# Tricky Test 2™: Genius Brain? 0.025
# Trials Frontier 0.025
# Trial Xtreme 4 0.025
# Trello 0.025
# Trebel Music - Unlimited Music Downloader 0.025
# TraptionBakery 0.025
# Trapdoors 0.025
# Transformers: Earth Wars 0.025
# TransParent Compass 0.025
# Trainline UK: Live Train Times, Tickets & Planner 0.025
# Train Conductor World 0.025
# Trailer Truck Parking with Real City Traffic Car Driving Sim 0.025
# Trail Jump 0.025
# Traffic Rider 0.025
# Traffic Racer 0.025
# Tracky Train 0.025
# Toy Blocks Game for Brain Traning -TSUMIKI- 0.025
# Toy Blast 0.025
# Township 0.025
# TownWiFi - WiFi Everywhere 0.025
# Tower Knights! 0.025
# Tower Conquest 0.025
# Touchdown Hero 0.025
# Total War Battles: KINGDOM 0.025
# Total - Free browser with file manager and cloud storage support 0.025
# Torque Burnout 0.025
# TopBuzz: Best Viral Videos, GIFs, TV & News 0.025
# Top Tier 0.025
# Top Model - Next Fashion Star 0.025
# Top Hat Lecture 0.025
# Top Eleven 2017 - Be a Soccer Manager 0.025
# Tooth Fairy Princess - Magical Adventure 0.025
# Toon Shooters 2: The Freelancers 0.025
# Tomb of the Mask 0.025
# Tom's Love Letters 0.025
# TohTum 0.025
# TodayAir 0.025
# Toca Kitchen Monsters 0.025
# Toca Hair Salon - Christmas Gift 0.025
# Toca Dance Free 0.025
# Toast Girl 0.025
# Titan Slots™ III 0.025
# Titan Brawl 0.025
# Tip Tap Soccer 0.025
# Tinycards - Learn with Fun, Free Flashcards 0.025
# Tiny Tower - Free City Building 0.025
# Tiny Sea Adventure 0.025
# Tiny Rails 0.025
# Tiny Miners 0.025
# Tiny Bone 0.025
# Tiny Archers 0.025
# Tinker Island: Survival Adventure 0.025
# Tinder 0.025
# Tina's Diary: Spring Outing 0.025
# Tina's Diary - Star Fever 0.025
# Timehop 0.025
# Timberman 0.025
# Tile - Find & track your lost phone, wallet, keys 0.025
# Tidal Rider 0.025
# Ticketmaster - Tickets for Concerts, Sports, Shows 0.025
# Ticket Scanner for Powerball & MegaMillions Pool 0.025
# Ticket Camp - フリマよりも安心で簡単なチケットアプリ 0.025
# Thumb Drift - Furious One Touch Car Racing 0.025
# Through The Fog! 0.025
# Thomas & Friends™: Read & Play 0.025
# Thomas & Friends: Race On! 0.025
# Thomas & Friends: Magical Tracks - Kids Train Set 0.025
# There's no tablecloth I can't pull!! 0.025
# Theory of evolution 0.025
# Themeboard 0.025
# ThemeOut 0.025
# The Weather Channel: Forecast, Radar & Alerts 0.025
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking 0.025
# The Washington Post Classic 0.025
# The Walls 0.025
# The Walking Dead: Road to Survival - Strategy Game 0.025
# The Walking Dead: No Man's Land 0.025
# The Walking Dead: Dead Yourself 0.025
# The Walk VR 0.025
# The Voice Official App on NBC 0.025
# The Trail 0.025
# The Singing Machine Mobile Karaoke App 0.025
# The Sims™ FreePlay 0.025
# The Simpsons™: Tapped Out 0.025
# The Silent Age 0.025
# The Secret Society® - Hidden Mystery 0.025
# The Sandbox Evolution - Craft a 2D Pixel Universe 0.025
# The Sandbox - Building & Crafting a Pixel World! 0.025
# The Rock Clock™ 0.025
# The Robot Factory by Tinybop 0.025
# The Quest Keeper 0.025
# The Pocket Quiz for Pokemon 0.025
# The Pit 0.025
# The Paranormal Society™: Hidden Adventure 0.025
# The Open 0.025
# The Olympics - Official App for the Olympic Games 0.025
# The Moron Test 0.025
# The Maze Runner ™ 0.025
# The Masters Tournament 0.025
# The Line Zen 0.025
# The Last Vikings 0.025
# The Krustashians 0.025
# The Impossible Quiz! 0.025
# The Impossible Letter Game 0.025
# The Higher Lower Game 0.025
# The Guardian 0.025
# The Counter Of Death 0.025
# The Cooking Game- With Cute iMessage Food Stickers 0.025
# The Clymb — Gear Deals 0.025
# The Championships, Wimbledon 2016 - Tennis Grand Slam 0.025
# The Calculator - Free and Easy Calculating! 0.025
# The CW 0.025
# The Bomb! 0.025
# The Blacklist: Conspiracy 0.025
# The Battle of Polytopia 0.025
# The Bad Man Tipster - Betting Tips 0.025
# TextNow - Unlimited Text + Calls 0.025
# Text Free: Free Texting + Calling + MMS 0.025
# Tetro Blocks - Beat IQ with Tetrix-style-puzzle. 0.025
# Tetris® Blitz 0.025
# Tetminos - Classic Puzzle Game 0.025
# TestNav 0.025
# TestFlight 0.025
# Test your color IQ！カラーIQ診断テスト２ 0.025
# Test your color IQ！カラーIQ診断テスト 0.025
# Tesla Tubes: Solve our Logic Games & Brain Puzzles 0.025
# Terra Monsters 3 0.025
# Tentacles - Enter the Mind 0.025
# Tennis Champs Returns 0.025
# Tennis Bits 0.025
# Temple Run 2 0.025
# Temple Run 0.025
# Telegram Messenger 0.025
# Teeter – Endless Arcade Balancer 0.025
# Teenage Mutant Ninja Turtles: Legends 0.025
# Teen Titans Go Arcade 0.025
# Team USA App 0.025
# Team GB Live 0.025
# Tchapper Messenger - Keep it private 0.025
# Tayasui Sketches 0.025
# Taxi Sim 2016 0.025
# TaxCaster – Free tax refund calculator 0.025
# Target Acquired 0.025
# Target 0.025
# Taps to Riches 0.025
# Tapping Monsters 0.025
# Tapage by My Little App 0.025
# Tap the Blocks 0.025
# Tap Tycoon - Country vs Country 0.025
# Tap Titans 2 0.025
# Tap Titans 0.025
# Tap Tap Trillionaire 0.025
# Tap Tap Fish - Abyssrium 0.025
# Tap Tap Dash 0.025
# Tap Tap Builder 0.025
# Tap Sports Baseball 2016 0.025
# Tap Smiths 0.025
# Tap Quest : Gate Keeper 0.025
# Tap My Katamari - Endless Cosmic Clicker 0.025
# Tap Hero 0.025
# Tap Cats: Idle Warfare 0.025
# Tantan 0.025
# Tankio - Battle Arena 0.025
# Tank.io war - Free Classic Tank games 0.025
# Tank.IO War - Free Tank games of snake 0.025
# Tank War - Geometry Go Shot Color Dot.IO 0.025
# Tango - Free Video Call, Voice and Chat 0.025
# Tangled Up! - Valentine Special 0.025
# Talking Tom Jetski 0.025
# Talking Tom Gold Run: Fun & Endless Running Game 0.025
# Talking Tom Cat for iPad 0.025
# Talking Tom Cat 2 for iPad 0.025
# Talking Tom Bubble Shooter 0.025
# Talking Tom & Ben News for iPad 0.025
# Talking Pierre the Parrot for iPad 0.025
# Talking Ginger for iPad 0.025
# Talking Ginger 2 0.025
# Talking Ben the Dog for iPad 0.025
# Talking Angela for iPad 0.025
# Talented Pets Show 0.025
# Tagesschau 0.025
# Tactile Wars 0.025
# TV SPIELFILM - TV Programm mit Live TV 0.025
# TRUTH or DARE!!! - FREE 0.025
# TRUMP'S WALL - Build it Huge 0.025
# TRUMP Yo'Self! Make Your Hair Great Again! 0.025
# TLMJ, Tout Le Monde Joue 0.025
# TLC GO - Watch Full Episodes and Live TV 0.025
# TIME LOCKER - Shooter 0.025
# TIDAL 0.025
# TETRIS® FREE 0.025
# TENOSEL+ 0.025
# TEDiSUB - Enjoy TED Talks with Subtitles 0.025
# TED 0.025
# TCS NYC Marathon 0.025
# TAP BRAIN - 1日5分の計算で頭が良くなるゲーム 0.025
# TALES OF LINK 0.025
# T-Mobile Tuesdays 0.025
# T-Mobile 0.025
# Symmetrica - Minimalistic arcade game 0.025
# Sworkit - Custom Workouts for Exercise & Fitness 0.025
# Swoopy Space 0.025
# Switchy Sides 0.025
# Swiperoo 0.025
# Swing 0.025
# Swift Playgrounds 0.025
# Sweet Tales: Match 3 Christmas 0.025
# Sweet Tales 0.025
# Sweet Princess Makeup Party - Girls Dressup Games 0.025
# Sweet Princess Beauty Salon 0.025
# Sweat: Kayla Itsines' Bikini Body Fitness Workouts 0.025
# SwapperFace - Face Swap Free, Live Mask Effects 0.025
# Swap Ball - Endless Arcade Bouncer 0.025
# Swamp Attack 0.025
# Swaggy Ninja 0.025
# Suрer Toss The Turtle 0.025
# Survivors: the Quest® 0.025
# Survivor: Prologue 0.025
# Surfingers 0.025
# Suppin Detective: Expose their true visage! 0.025
# Supermodel Star - Rule the Runway 0.025
# Supermarket Girl - Shopping Fun! 0.025
# Superdrug 0.025
# SuperPhoto - Photo Effects & Filters 0.025
# Super Stickman Golf 3 0.025
# Super Stickman Golf 2 0.025
# Super Smash the Office - Endless Destruction! 0.025
# Super Slime Blitz – Gumball Endless Arcade Climber 0.025
# Super Phantom Cat - Be a jumping bro. 0.025
# Super Mario Run 0.025
# Super Knock and Run 0.025
# Super Jabber Jump 0.025
# Super Fashion Show - Girls Makeup, Dressup Games 0.025
# Super Duper Punch 0.025
# Super Cat Tales 0.025
# Super Candy: Let's Fix it! 0.025
# Super Atomic 0.025
# Super Adventures World HD 0.025
# Sunken Secrets 0.025
# Sunday Ticket 0.025
# Summoners War 0.025
# Summer Vacation - Fun at the Beach 0.025
# Sumikko gurashi-Puzzling Ways 0.025
# Suicide Squad: Special Ops 0.025
# Suicaチャージ 0.025
# Suica 0.025
# Sugar Smash: Book of Life 0.025
# Sugar Slide: The Path Home 0.025
# Subway Surfers 0.025
# Stylish School Timetable 0.025
# Stupid Zombies 3 0.025
# Stupid Test! 0.025
# Stupid Again 0.025
# StubHub - Tickets to Sports, Concerts and Theatre 0.025
# String Rush 0.025
# Stretch Dungeon 0.025
# Stress Release Grenade 0.025
# Street Fighter Puzzle Spirits 0.025
# Strawberry Shortcake Holiday Hair - Fashion World 0.025
# Strawberry Shortcake Dress Up Dreams 0.025
# Strawberry Shortcake Candy Garden 0.025
# Stormfall: Rise of Balur 0.025
# Storm Radar 0.025
# Stop! Thief!! 0.025
# Stop Curry 0.025
# Stop - Fun Categories Word Game 0.025
# Stony Road 0.025
# Stirfry Stunts – We Bare Bears Cooking Game Starring Chef Ice Bear 0.025
# StickyBalls Deluxe - Addicting Fall Down Game 0.025
# Stickninja Smash 0.025
# Stickman Soccer 2016 0.025
# Stickman Ice Hockey 0.025
# Stickman Forest Swing 0.025
# Stickman Football 0.025
# Stickman Cubed 0.025
# Stickman Basketball 2017 0.025
# Stickman Base Jumper 2 0.025
# Sticklings 0.025
# Stick Soccer 2 0.025
# Stick Hero 0.025
# Steve - The Jumping Dinosaur Widget Arcade Game 0.025
# Steps! - Hardest Action Game Ever! 0.025
# Steps 0.025
# Steppy Pants 0.025
# Stay in the Line - Free 0.025
# State Council - Official Chinese government app 0.025
# Stash Invest: Investing & Financial Education 0.025
# Starfall Learn to Read 0.025
# Starfall FREE 0.025
# Starbucks Keyboard 0.025
# Starbucks 0.025
# Star Wars™: Galaxy of Heroes 0.025
# Star Wars™: Commander 0.025
# Star Wars™ Force Band™ by Sphero 0.025
# Star Walk 2 Ads+ Night Sky Map - Stars and Planets 0.025
# Star Trek ® - Wrath of Gems 0.025
# Star Trek Timelines 0.025
# Star Skater 0.025
# Star Cheerleader - High School Tryouts 0.025
# Star Chart 0.025
# StageCameraHD 0.025
# Stage Rush: Imagine Dragons 0.025
# Stack 0.025
# Squaready for Video - Convert Rectangle Movie Clip into Square Shape for Instagram 0.025
# Square Cash - Send Money for Free 0.025
# Sprinkle of Jesus 0.025
# Spring Festival by BabyBus 0.025
# Spotify Music 0.025
# Spot the Difference!診断テスト 0.025
# SportsManias: Sports Emojis, Fantasy & Team News 0.025
# Sports Hero 0.025
# Spoon Pet Collector 0.025
# Splish Splash Pong 0.025
# Splice - Video Editor + Movie Maker by GoPro 0.025
# Splat Wars 0.025
# Splashy Cats: Endless Zigzag Arcade Water Game 0.025
# Splash Pop 0.025
# Splash Cars 0.025
# Splash 0.025
# Spirit Rush 0.025
# Spiral Tower 0.025
# Spiral Splatter 0.025
# Spinrilla - Mixtapes For Free 0.025
# Spinny Phone 0.025
# Spinny Circle 0.025
# Spinning Rings 0.025
# Spin It Rich! Casino Slots: Free Slot Machines 0.025
# Spike Run 0.025
# Spider Solitaire ∙ 0.025
# Spider Solitaire Free by MobilityWare 0.025
# Spellspire 0.025
# SpellingCity 0.025
# Spellbinders 0.025
# Speedtest by Ookla 0.025
# Speech Jammer 0.025
# Speakaboos Reading App: Stories & Songs for Kids 0.025
# Speak & Translate － Voice and Text Translator 0.025
# Sparkwave 0.025
# Sparkasse - Your mobile branch 0.025
# Spanish SOLO: Learn Spanish With Lessons On The Go 0.025
# Spa Birthday Party - Nails, Hair, Dress Up & Cake 0.025
# Southwest Airlines 0.025
# Soundtrack Attack - Steven Universe Rhythm Runner 0.025
# Sounds app - Music And Friends 0.025
# SoundHound Song Search & Music Player 0.025
# SoundCloud Pulse: for creators 0.025
# SoundCloud - Music & Audio 0.025
# Sophia - My Little Sis 0.025
# Sonos Controller 0.025
# Sonic Dash 2: Sonic Boom 0.025
# Sonic Dash 0.025
# Sonic CD 0.025
# Sonic & All-Stars Racing Transformed 0.025
# Sonia Tlev 0.025
# SongPop 2 - Guess The Song 0.025
# SongFlip - Free Music Streamer 0.025
# Solo Selfie 0.025
# Solitaire· 0.025
# Solitaire ▪ 0.025
# Solitaire Ⓞ 0.025
# Solitaire ∞ 0.025
# Solitaire ∘ 0.025
# Solitaire TriPeaks: Classic Card Game 0.025
# Solitaire One 0.025
# Solitaire Free: card games for adults 0.025
# Solitaire Deluxe® Social - Classic, Spider, more 0.025
# Solitaire Classic Card Game™ 0.025
# Solitaire 0.025
# SofaScore Live Sports: Scores, VIDEO & Stats 0.025
# Soda World - Your Soda Inc 0.025
# Soda Dungeon 0.025
# Soda Coin Party: Free Casino Pusher 0.025
# Socrative Student 0.025
# Social Picket - Stalker & Spy for Instagram 0.025
# Soccer Stars™ 0.025
# Soccer Star 2016 World Legend 0.025
# Soccer Stadium Sports Car & Bus Parking Simulator 3D Driving Sim 0.025
# Soccer Puzzle for Brain Training -SoccerStrike- 0.025
# Soccer Hit 0.025
# Soccer Cup Championship 2016 0.025
# Soccer Clicker 0.025
# Snowboarding The Fourth Phase 0.025
# Snow Roll 0.025
# SnoreLab : Record Your Snoring 0.025
# Sniper: Traffic Hunter 0.025
# Sniper Shooter: Gun Shooting Games 0.025
# Sniper Fury: Fun Mobile Shooter Game 0.025
# Sniper 3D Assassin: Shoot to Kill Gun Game 0.025
# Snapseed 0.025
# Snapimals: Discover & Snap Amazing & Cute Animals! 0.025
# Snapchat 0.025
# SnapMatch - Single and Group Matching 0.025
# Snakeio 0.025
# Snakebird 0.025
# Snake.io - Worm.io - Agar Slither Snake Battle 0.025
# Snake splix 0.025
# Snake Slither Run - Hungry Worm Eat Color Dot 0.025
# Snail Sleep-Dream Talk Recording 0.025
# Snail Bob 2 0.025
# Smurfs Epic Run - Fun Platform Adventure 0.025
# Smule Sing! 0.025
# Smelly Baby - Farty Party 0.025
# Smashy Road: Wanted 0.025
# Smashy Road: Arena 0.025
# Smashy City 0.025
# Smash Slots 0.025
# Smash Monsters - City Rampage 0.025
# Smash Hit 0.025
# Smash Fu - Endless Arcade Smasher 0.025
# SmartNews - Trending News & Stories 0.025
# SmartFit - Wristband 0.025
# Smart Virtual Boyfriend 0.025
# Smart Music: Streaming Videos and Radio 0.025
# Smart Matches ~ Puzzles with Matchsticks 0.025
# Smart Channel -New Style of News Reader- 0.025
# Smart Alarm Clock : sleep cycle & snoring recorder 0.025
# Slots: VIP Deluxe Slots Machines - Free Slot Games 0.025
# Slots: Hot Vegas Slot Machines - Free Slot Games 0.025
# Slots: Get Rich Slot Machines Casino Slot Games 0.025
# Slots: Fast Fortune Slot Machines & Fun Slot Games 0.025
# Slots: DoubleUp Free Slot Games - Slot Machines 0.025
# Slots of Vegas - Play Free Casino slot machines! 0.025
# Slots Real Las Vegas - Free Casino Slot Machine Games - Bet, Spin and Win Jackpot & Bonus 0.025
# Slots Discovery 0.025
# Slots - Pharaoh's Way 0.025
# Slots - Lucky Win Casino Games & Slot Machines 0.025
# Slots - Huuuge Casino: Slot Machines 0.025
# Sloomy 0.025
# Slip Away 0.025
# Slingshot Rush 0.025
# Sling TV: A La Carte TV. Watch Live Shows & Sports 0.025
# Sling Kong 0.025
# SlideStory - Create a slideshow movie and a snap video 0.025
# Slide the Shakes 0.025
# Sleep Talk Recorder 0.025
# Sleep Meister - Sleep Cycle Alarm Lite 0.025
# Sleep Cycle alarm clock 0.025
# Slaymoji - Emoji Keyboard & iMessage Stickers 0.025
# Slash Mobs 0.025
# Slam Dunk Basketball 2 - Play & Do Good 0.025
# Skype for iPhone 0.025
# Skype for iPad 0.025
# Skyline Skaters 0.025
# Skylanders™ Creator 0.025
# Skylanders SuperChargers 0.025
# Skylanders Battlecast 0.025
# SkyView® Free - Explore the Universe 0.025
# Sky Whale - a Game Shakers App 0.025
# Sky Viper Video Viewer 0.025
# Sky Viper Flight Simulator 0.025
# Sky Pillar 0.025
# Sky News 0.025
# Sky Hoppers 0.025
# Sky Force Reloaded 0.025
# Sky Chasers 0.025
# Sky Charms 0.025
# Sky Burger - Build & Match Food Free 0.025
# Skippy Box 0.025
# Skiplagged — Actually Cheap Flights & Hotels 0.025
# Skinseed - Skin Creator for Minecraft Skins 0.025
# SkillTwins Football Game 0.025
# Skiing Yeti Mountain 0.025
# Ski Resort Parking Sim Ice Road Snow Plow Trucker 0.025
# SketchBook Motion 0.025
# Six! 0.025
# Six Flags 0.025
# Sisters: A Virtual Reality Ghost Story 0.025
# Sir Match-a-Lot – Match 3 Puzzle Game 0.025
# Sing Karaoke Songs Unlimited with StarMaker 0.025
# Simulator Run Real Hologram 0.025
# Simulator Hoverboard 0.025
# Simply Piano by JoyTunes - Learn & play piano 0.025
# Simple Reversi Online 0.025
# Simple Radio - Live AM & FM Radio Stations 0.025
# Simple Habit 0.025
# Simple Camera - Fast Minimal Design 0.025
# Simeji - Japanese Keyboard with Emoticons 0.025
# SimSimi 0.025
# SimCity BuildIt 0.025
# Silly Sausage: Doggy Dessert 0.025
# Sideline - 2nd Phone Number 0.025
# Shutterfly: Prints, Photo Books, Cards Made Easy 0.025
# Shuffle Cats 0.025
# Shpock Boot Sale & Classifieds App. Buy & Sell 0.025
# Showroomprive - Private Fashion Sales 0.025
# Show My Homework 0.025
# Shoutrageous! - The Addictive Game of Lists 0.025
# Shopular Coupons, Weekly Deals for Target, Walmart 0.025
# Shopping Mall Girl - Dress Up & Style Game 0.025
# Shopping Mall Car Parking Simulator a Real Driving Racing Game 0.025
# Shopkins: Chef Club 0.025
# ...
# Chef's Quest 0.025
# Chef Siblings - Island Restaurant 0.025
# Checkout 51: Grocery Coupons & Cash Back Savings 0.025
# Cheats For Pokemon Go - Gameplay, PokeCoins Guide, Catch Videos 0.025
# Chatous - Chat with new people 0.025
# Chat for Whatsapp - iPad Version 0.025
# Chat for Pokemon Go - GoChat 0.025
# Chase Mobile℠ 0.025
# Chase Mobile 0.025
# Charity Miles: Walking & Running Distance Tracker 0.025
# Charades!™ 0.025
# Chaos Chronicle 0.025
# Chaos Centurions 0.025
# Champs Sports 0.025
# Championship Manager 17 0.025
# Chain: Collaborate On MyVideo Story/Group Video 0.025
# Certified Mixtapes - Hip Hop Albums & Mixtapes 0.025
# Century City 0.025
# Celebtwin: Celebrity Looks Like Lite 0.025
# CelebrityDiagnosis! 0.025
# CelebrityCamera! 0.025
# Celebrity Look Alike App - Face Compare 0.025
# Catch the Bus 0.025
# Catch Santa Claus in my house for Christmas 0.025
# Catch Rate 0.025
# CatHotel - Care for cute cats 0.025
# Cat-A-Pult: Endless stacking of 8-bit kittens 0.025
# Cat Monsters 0.025
# Cat Kitty Kitten Coloring Pages - Free Girl Games 0.025
# Castle Crush: Epic Strategy Game 0.025
# Castle Clash: Brave Squads 0.025
# Casino X - Free Slot Machines, Poker, Blackjack 0.025
# Casino Girl-お金稼ぎ美少女育成ゲーム- 0.025
# Cascade: Fun Spin and Match Puzzle Game 0.025
# Cartwheel by Target 0.025
# Cartoon Wars 3 0.025
# Cartoon Network App – Teen Titans Go! And more! 0.025
# Card Wars Kingdom - Adventure Time 0.025
# Car Factory Parking Simulator a Real Garage Repair Shop Racing Game 0.025
# Capture - Control Your GoPro Camera - Share Video 0.025
# Capital One for iPad 0.025
# Capital One Mobile 0.025
# Capital One CreditWise - Credit score and report 0.025
# Canvas by Instructure 0.025
# Canva - Graphic Design & Photo Editing 0.025
# Canon PRINT Inkjet/SELPHY 0.025
# Candy's Vacation - Beach Hotel 0.025
# Candy's Carnival 0.025
# Candy Party: Coin Carnival Dozer 0.025
# Candy Makeup - Sweet Salon Game for Girls 0.025
# Candy Crush Soda Saga 0.025
# Candy Crush Saga 0.025
# Candy Crush Jelly Saga 0.025
# Candy Camera 0.025
# Candy Blast Mania 0.025
# Candid - Speak Your Mind Freely 0.025
# Can You Escape 0.025
# Can You Dab? 0.025
# Camp Pokémon 0.025
# Camera360 - Selfie Filter Camera, Photo Editor 0.025
# Camcorder - Record VHS Home Videos 0.025
# Calorie Counter & Diet Tracker by MyFitnessPal 0.025
# Call of Duty®: Heroes 0.025
# Calculator‰ 0.025
# Calculator for iPad Free. 0.025
# Calculator Pro for iPad Free - Smart Calculator 0.025
# Calculator HD Free 0.025
# Cake Break 0.025
# Cafe Story - Play Cooking & Farming Game 0.025
# Caf - Mon Compte 0.025
# CVS Pharmacy 0.025
# CVS 0.025
# CUBE 360°　～想像力×知能×反射神経～ 0.025
# CTFxCmoji 0.025
# CSR Racing 2 0.025
# CSR Racing 0.025
# CSR Classics 0.025
# CROSS -よけてすすむ爽快アクション- 0.025
# CPlus for Craigslist app - mobile classifieds 0.025
# COOKING MAMA Let's Cook！ 0.025
# CNN: Breaking US & World News, Live Video 0.025
# CNN Politics 0.025
# CLUE Bingo: Valentine’s Day 0.025
# CLUE Bingo 0.025
# CHiP - Your New Best Friend 0.025
# CCTV5 0.025
# CBS Sports App - Sports Scores, News, Stats, Watch 0.025
# CBS News - Watch Free Live Breaking News 0.025
# CBS Full Episodes and Live TV 0.025
# CATCHY Photos-Easter Bunny, Tooth Fairy and more.. 0.025
# C CHANNEL -Watch tips & tricks videos for girls 0.025
# Buzzy Bubbles 0.025
# BuzzTube - Video Player for YouTube 0.025
# BuzzFeed Video 0.025
# Butt Sworkit - Free Workout Trainer to tone & lift 0.025
# Bushido Bear 0.025
# Bus Driving Taxi Parking Simulator Real Extreme Car Racing Sim 0.025
# Burrito Bison: Launcha Libre 0.025
# Burnout City 0.025
# Burgers & Shakes - Fast Food Maker 0.025
# Burger – The Game 0.025
# Burger Jump 0.025
# Bumper Jump 0.025
# Bumble – Find a Date, Meet Friends & Network 0.025
# Bullet Hell Monday 0.025
# Bullet Force 0.025
# Bullet Boy 0.025
# Buildy Blocks 0.025
# Building World - Create Your Castle & City 0.025
# Builder Buddies: 3D City Building Simulator 0.025
# Build Away! - Idle City Game 0.025
# Buffalo Slots - Royal Casino Fun Slot Machines! 0.025
# Buddyman Run － keep running! 0.025
# Buddy Toss 0.025
# Bud Farm: Grass Roots 0.025
# Bubble Shoot Pet 0.025
# Bubble Mania™ 0.025
# Bubble Island 2 - Pop Bubble Shooter 0.025
# Bubble Buggie 0.025
# Brutal Street 0.025
# Bruh-Button 0.025
# Browser and File Manager for Documents 0.025
# Britney Spears: American Dream 0.025
# Brio - Don’t Fall! 0.025
# Bridge Rider 0.025
# Bridge Construction Simulator 3D a Real City Building Physics Sim 0.025
# Bridge 0.025
# Brick Splits 0.025
# Brick Shot 0.025
# Brick Rage - Not for the Weak Heart 0.025
# Break Liner 0.025
# Brake or Break 0.025
# BrainTraining!!GASHAAAAAAN!! 0.025
# BrainHQ - Brain Training 0.025
# Brain15 − 脳トレ 無料パズル − 0.025
# Brain Dots - Draw and solve! Brain Training Game 0.025
# Brain Block -脳トレ分解パズル- 0.025
# Boyfriend Plus - Brett Jeff and Kai 0.025
# BoycottTrump 0.025
# Bowmasters - Top Multiplayer Bowman Archery Game 0.025
# Bowling King 0.025
# Bouncy Tower 0.025
# Bouncy Kingdom 0.025
# Bouncing Ball 2 0.025
# Bounce Balls - Strike Game 0.025
# Bottle Flip! 0.025
# Bottle Flip 2k16 0.025
# Bose SoundTouch 0.025
# Bose Connect 0.025
# Boooom!! -たった1発で爆破できますか？- 0.025
# Boomerang from Instagram 0.025
# Boom: Best Equalizer & Magical Surround Sound 0.025
# Boom Boom Soccer 0.025
# Boom Boom Football 0.025
# Boom Beach 0.025
# Bookshelf 0.025
# BookShout: Read eBooks & Track Your Reading Goals 0.025
# Book - room escape game - 0.025
# Boo - The World's Cutest Dog Game! 0.025
# Bonk! Presented by The Tonight Show Starring Jimmy Fallon 0.025
# Bonecrusher: Free Awesome Endless Skull & Bone Game 0.025
# Bon Appetit 0.025
# Bold Moves 0.025
# BlurEffect-Blur Photo & Video, Hide Face 0.025
# Blue Apprentice Elementary Science Game by Galxyz 0.025
# Bloxels: Build, Play & Share Your Own Video Games 0.025
# Blossom Blast Saga - Fun Flower Match & Grow Game 0.025
# Bloons TD Battles 0.025
# Blocs Wave - Make & Record Music 0.025
# Blocky Soccer - Endless Arcade Runner 0.025
# Blocky Racer - Endless Arcade Racing 0.025
# Blocky Hockey - Arcade Ice Runner 0.025
# Blocky Football 0.025
# Blocky Basketball - Endless Arcade Dunker 0.025
# Block! Hexa Puzzle 0.025
# Block Сity Wars: game and skin export to minecraft 0.025
# Block Craft 3D: Building Simulator Game For Free 0.025
# Blitz Brigade: Multiplayer FPS shooter online! 0.025
# Blink Health 0.025
# Bleacher Report: Sports news, scores, & highlights 0.025
# BlazBlue RR - the Real Action Game 0.025
# Blair's Fashion Boutique - School Style 0.025
# Blade Sliders 0.025
# Blackjack by MobilityWare 0.025
# Blackbox - think outside the box 0.025
# Blackboard Mobile Learn™ 0.025
# Black Hole -世の中で最も困難な物理げーむ ぱずる- 0.025
# Black Friday 2017 Ads App - BlackFriday.fm 0.025
# Black Box - Black Movie List 0.025
# BlaBlaCar - Trusted Carpooling 0.025
# Bits of Sweets 0.025
# Bitmoji - Your Personal Emoji 0.025
# Bitauto Autoprice 0.025
# Bingo!™ 0.025
# Bingo Pop 0.025
# Billionaire – Business Capitalist Tycoon! 0.025
# Billion Hunter - Casual Monster Clicker RPG 0.025
# Billiards9 0.025
# Billiards8 (8 Ball & Mission) 0.025
# Bike Unchained 0.025
# Bike Traffic Rider an Extreme Real Endless Road Racer Racing Game 0.025
# Bike Race Level 100 0.025
# Bike Race - Top Motorcycle Racing Games 0.025
# Big Win Football 2016 0.025
# Big Fish Casino – Best Vegas Slot Machines & Games 0.025
# Big Bang Racing 0.025
# Bible 0.025
# BiBi娱乐社区 - 好玩的游戏都在这里！ 0.025
# Beyond 14 0.025
# BestieBox 0.025
# Bestie-Beauty Camera 360 & Portrait Selfie Editor 0.025
# Best Fiends Forever 0.025
# Best Fiends 0.025
# Best Buy 0.025
# Best 9 for Instagram 0.025
# Bernie Sandwiches - Run For The White House 0.025
# Beneath The Lighthouse 0.025
# Bella's Pizza Place - Italian Food Maker 0.025
# Bejeweled Stars 0.025
# Bejeweled Classic HD 0.025
# Bejeweled Classic 0.025
# Bejeweled Blitz 0.025
# Being SalMan: The Official Game 0.025
# Behind You!! 0.025
# Beer Pong Game 0.025
# Bee Brilliant 0.025
# BeautyPlus - Selfie Camera for a Beautiful Image 0.025
# BeautyCam - AR Carnie selfie 0.025
# Beautiful Japanese Handwriting for iPhone 0.025
# Beautiful Japanese Handwriting 0.025
# Beat the Boss 4 0.025
# Beat the Boss 2 0.025
# Beat Racer 0.025
# Beast Poker 0.025
# Bear Pop - Bubble Shooter Game 0.025
# Bear 0.025
# Beach Buggy Racing 0.025
# Bazaart Photo Editor Pro and Picture Collage Maker 0.025
# Battlestar Galactica: Squadrons™ 0.025
# Battleplans - #1 Battle Strategy & Defense Game 0.025
# Battlefield™ Companion 0.025
# Battleborn® Tap 0.025
# BattleHand 0.025
# Battle Golf 0.025
# Battle Copters 0.025
# Battle Camp HD - Collect & Evolve Your Monsters 0.025
# Battle Bears Overclock FPS Epic Multiplayer Shooting Games 0.025
# Batman: Arkham Underworld 0.025
# Batman: Arkham Origins 0.025
# Batman v Superman: Who Will Win 0.025
# Basketball Stars™ 0.025
# Basketball Free Throw 0.025
# Basketball Clicker 0.025
# Basket Fall - Basketball Dunking Sim 0.025
# BarcodeReader「ICONIT」 0.025
# Barbie Dreamtopia - Magical Hair 0.025
# Bank of America - Mobile Banking for iPad 0.025
# Bank of America - Mobile Banking 0.025
# Bandsintown Concerts 0.025
# Ball Tower 0.025
# Ball Maze! 0.025
# Ball King 0.025
# Ball Escape! 0.025
# Bakery Story 2 0.025
# Bakery Blitz: Cooking Game 0.025
# Baidu Videos 0.025
# Badoo - Meet New People, Chat, Socialize. 0.025
# Bad Piggies HD 0.025
# Bad Piggies 0.025
# Back To Square One 0.025
# Babysitter Madness - Help the Nanny 0.025
# Babysitter Craziness - Fun Kids Game 0.025
# Baby Twins - Terrible Two 0.025
# Baby Story - Pregnancy Pics Baby Milestones Photo 0.025
# Baby Skins and Aphmau Skins and Boy Skins and Girl Skins For Minecraft PE 0.025
# Baby Panda's Carnival 0.025
# Baby Panda's Bath Time 0.025
# Baby Learns Transportation 0.025
# Baby Kim - Care, Play & Dress Up 0.025
# Baby Full House - Care, Play and Have Fun 0.025
# Baby Food Fair - Make, Eat, Play - Have Fun! 0.025
# Baby Care & Dress Up - Love & Have Fun with Babies 0.025
# Baby Bottle Challenge - Water Bottle Flip 0.025
# Baby Boss - Care, Dress Up and Play 0.025
# Baby Airlines - Airport Adventures 0.025
# Babbel – Learn Languages Spanish, French & more 0.025
# BTN2Go 0.025
# BOSS Tuner 0.025
# BOO! - Video chat camera with filters & stickers 0.025
# BLOCK(ブロック) -ぼくの箱庭【3D】- 0.025
# BLEACH 公式連載アプリ〜BLEACHの漫画が毎週１巻読めるアプリ〜 0.025
# BLEACH Brave Souls 0.025
# BIG WIN Basketball 0.025
# BFMTV : l'info en continu 0.025
# BFB Champions 2.0 ~Football Club Manager~ 0.025
# BET NOW - Watch Shows 0.025
# BEAKER by THIX 0.025
# BBTAN by 111% 0.025
# BB-8™ App Enabled Droid Powered by Sphero 0.025
# BARRIER X 0.025
# BAA Marathon 0.025
# B612 - Trendy Filters, Selfiegenic Camera 0.025
# Axe in Face 2 0.025
# Autohome-Find new＆Used Cars For Sale 0.025
# AutoScout24 - mobile used & new car market 0.025
# AutoRap by Smule 0.025
# Auto Warriors - Tactical Car Combat 0.025
# Auto Palmistry 0.025
# Auto IV Calc for PokemonGO 0.025
# Aussie Rules Hero - Footy Goal Kicking Game 0.025
# Auralux: Constellations 0.025
# Audible – audio books, original series & podcasts 0.025
# Attenborough Story of Life 0.025
# Atom – Movie Tickets and Showtimes 0.025
# Athletics 2: Summer Sports - Free 0.025
# Athlete Shave Salon Games 0.025
# Asterix and Friends 0.025
# Assassin's Creed Pirates 0.025
# Asphalt Xtreme: Offroad Rally Racing 0.025
# Asphalt 8: Airborne 0.025
# Asana Rebel - Yoga Inspired Fitness 0.025
# Artisto – Video and Photo Editor with Art Filters 0.025
# Arrow Ambush 0.025
# Arrow 0.025
# Army of Heroes 0.025
# Arma Mobile Ops 0.025
# Are you a psychopath? 怖い心理テスト 0.025
# Archery King 0.025
# Arcane Online - Fantasy MMORPG 0.025
# Aquarium VR 0.025
# April - Layouts, Photo Collage, and Poster Maker 0.025
# Apple TV Remote 0.025
# Apple Support 0.025
# Apple Store 0.025
# Ao Oni2 0.025
# Anki OVERDRIVE 0.025
# Anime Power FX 0.025
# Animation Throwdown: The Quest for Cards 0.025
# Animal Jam - Play Wild! 0.025
# Angry Birds Transformers 0.025
# Angry Birds Star Wars II 0.025
# Angry Birds Star Wars HD 0.025
# Angry Birds Star Wars 0.025
# Angry Birds Space HD 0.025
# Angry Birds Space 0.025
# Angry Birds Seasons HD 0.025
# Angry Birds Rio HD 0.025
# Angry Birds Rio 0.025
# Angry Birds POP! - Bubble Shooter 0.025
# Angry Birds HD 0.025
# Angry Birds Go! 0.025
# Angry Birds Friends 0.025
# Angry Birds Epic RPG 0.025
# Angry Birds Blast 0.025
# Angry Birds Action! 0.025
# Angry Birds 2 0.025
# Angry Birds 0.025
# Amusement Park Tour 2: Fun Xmas 0.025
# Amusement Park Tour 0.025
# Amusement Park Fair Ground Circus Trucker Parking Simulator 0.025
# AmpMe - A Portable Social Party Music Speaker 0.025
# Amex Mobile 0.025
# Ameba 0.025
# Amazon Prime Video 0.025
# Amazon Prime Now 0.025
# Amazon Music 0.025
# Amazon App: shop, scan, compare, and read reviews 0.025
# Amazon Alexa 0.025
# Amazing Thief 0.025
# Amateur Surgeon 4 0.025
# Alternative Girls 0.025
# Alpha Omega 0.025
# Alpaca World HD+ 0.025
# Almanac Long-Range Weather Forecast 0.025
# Allrecipes Dinner Spinner 0.025
# AlloCiné : Cinéma et Séries 0.025
# Alliance: Air War - Airplane Flight Simulator Game 0.025
# Alliance Wars: World Domination 0.025
# All is Lost 0.025
# All Star Quarterback 17 - Football Lifestyle Sim 0.025
# All Limpy Run! 0.025
# All Devices for WhatsApp - Messenger for iPad 0.025
# Alipay - Makes Life Easy 0.025
# Alice in the Mirrors of Albion: Hidden object game 0.025
# AliExpress Shopping App 0.025
# Alarm Clock for Me - Best Wake Up Music & Clock 0.025
# Alarm Clock HD Free - Digital Alarm Clock Display 0.025
# Akinator the Genie FREE 0.025
# Airbnb 0.025
# AirWatch Agent 0.025
# AgingBooth 0.025
# Age of Heroes: Conquest 0.025
# Agar.io 0.025
# Again - room escape game 0.025
# Afterpulse 0.025
# After School - Funny Anonymous School News 0.025
# Aeronaut 0.025
# Adventure Cube 0.025
# Adventure Company 0.025
# Advent Calendar 2017 - The Game 0.025
# Adobe Spark Video, Animated Videos in minutes 0.025
# Adobe Spark Page — Create Stunning Web Pages 0.025
# Adobe Photoshop Mix - Cut out, combine, create 0.025
# Adobe Photoshop Lightroom for iPhone 0.025
# Adobe Photoshop Lightroom for iPad 0.025
# Adobe Illustrator Draw 0.025
# Adobe Acrobat Reader: View, Create, & Convert PDFs 0.025
# AdVenture Capitalist 0.025
# Action Movie FX 0.025
# Ace Fishing: Wild Catch 0.025
# AccuWeather - Weather for Life 0.025
# Acapella from PicPlayPost 0.025
# AbemaTV-インターネットテレビ局 0.025
# Ab in den Urlaub – Pauschalreisen günstig buchen 0.025
# Ab & Core Sworkit - Free Workout Trainer 0.025
# ATracker - Daily Task and Time Tracking 0.025
# AT&T Mobile Transfer - Free 0.025
# ASOS 0.025
# AOL: News, Email, Weather & Video 0.025
# AMC 0.025
# ALOE -ダイエット・ヨガ・エクササイズ…健康美を追求する女性の人気無料ニュースアプリ 0.025
# AKUMA大戦 -悪魔を合体召喚して魔王を育成する放置ゲーム- 0.025
# AGT: America's Got Talent Official App on NBC 0.025
# AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes 0.025
# ADP Mobile Solutions 0.025
# ABCmouse.com - Early Learning Academy 0.025
# ABC – Watch Live TV & Stream Full Episodes 0.025
# ABC News - US & World News + Live Video 0.025
# A.P.E.X 0.025
# A Color Story 0.025
# A Call From Santa! Voicemail & Text Messages 0.025
# 9回裏だけ甲子園 0.025
# 94% 0.025
# 8fit - Workouts, meal plans and personal trainer 0.025
# 8-BIT WATERSLIDE 0.025
# 8 Ball Pool™ 0.025
# 777游戏厅-2017超人气掌上游戏厅 0.025
# 7-Eleven, Inc. 0.025
# 6play, TV en direct et en replay 0.025
# 5miles: Buy and Sell Used Stuff Locally 0.025
# 5E Spell Book 0.025
# 58同城-招聘找工作兼职租房软件 0.025
# 51信用卡管家 0.025
# 50 50 - The Addictive Slicing Game 0.025
# 4x4 Dirt Track Trials Forest Driving Parking Sim 0.025
# 400ステージに挑戦！ばあジャンプ 0.025
# 4 Pics 1 Word 0.025
# 4 Images 1 Mot 0.025
# 4 Bilder 1 Wort 0.025
# 3D Maze Level 100 0.025
# 3D Dubai Parking Simulator Drive Real Extreme Super Sports Car 0.025
# 3D Car Racing Simulator Real Drag Race Rivals Road Chase Driving Games 0.025
# 365Scores 0.025
# 360手机浏览器-安全上网看新闻、安心搜索、极速抢票 0.025
# 360手机卫士-超安全的来电防骚扰助手 0.025
# 360云盘 0.025
# 360 Degree 0.025
# 30秒マン-これクリアできるやついる？- 0.025
# 2代目 Nソウル みそぽん 0.025
# 2Face Fitpack - Dein Trainingsprogramm mit persönlichem Ernährungsplan, Kalorienrechner und Trainingsplan 0.025
# 270toWin 0.025
# 25 Days of Christmas: Holiday Advent Calendar 2016 0.025
# 2048 0.025
# 2016 US Open Tennis Championships 0.025
# 2016 U.S. Open Golf Championship for iPad 0.025
# 2016 U.S. Open Golf Championship 0.025
# 20 Minutes.fr - l'actualité en continu 0.025
# 1号店-全球超市 轻松到家 0.025
# 1600 0.025
# 12オーディンズ - 王道RPG 0.025
# 1010! 0.025
# 1000m Zombie Escape! 0.025
# 100! Block Puzzle - Color jigsaw 10x10 board game 0.025
# 100 PICS Quiz - guess the picture trivia games 0.025
# 100 PICS Coloring - free color in book game app 0.025
# 100 Balls 0.025
# 10 – 頭を良くするパズル 0.025
# 1-Bit Rogue: A dungeon crawler RPG! 0.025
# 1+2=3 0.025
# . Calculator . 0.025
# -The 穴通し3D- 君の記憶力x反射神経を問う! ～Mr.CURVEからの挑戦状 ～ 0.025
# *Solitaire* 0.025
# ! OH Fantastic Free Kick + Kick Wall Challenge 0.025

# %% [markdown]
# - The scene on Google Play appears to be very different now; there don't seem to be as many games and it seems like most apps are made for family, tools, business, lifestyle, productivity, etc. If we look into this further, we see that the family category—which includes over 19% of all apps—primarily refers to children's games.

# %% [markdown]
# ### Analyzing Most Popular Apps by Genre

# %% [markdown]
# - Now we want to determine the kind of apps with the most users
#
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of `Installs` for each genre. This info exists in the google play store dataset but is missing from the AppleStore dataset. We use the `rating_count_tot` column as a proxy

# %%
# Looping over the prime_genre column in the Applestore dataset

def freq_table(dataset, index):
    prime_genre_table = {}
    total_number_of_apps = 0
    
    for element in dataset:
        total_number_of_apps += 1
        genre = element[index]
        
        if genre in prime_genre_table:
            prime_genre_table[genre] += 1
        else:
            prime_genre_table[genre] = 1

    return prime_genre_table

# %%
prime_freq = freq_table(free_ios_apps, 11)

for genre in prime_freq:
    total = 0
    len_genre = 0
    for element in free_ios_apps:
        genre_app = element[11]
        if genre_app == genre:
            user_rating = float(element[5])
            total += user_rating
            len_genre += 1
    average_user_rating = total / len_genre
    print(genre, ':', average_user_rating)
# Out:
# Social Networking : 53078.195804195806
# Photo & Video : 27249.892215568863
# Games : 18924.68896765618
# Music : 56482.02985074627
# Reference : 67447.9
# Health & Fitness : 19952.315789473683
# Weather : 47220.93548387097
# Utilities : 14010.100917431193
# Travel : 20216.01785714286
# Shopping : 18746.677685950413
# News : 15892.724137931034
# Navigation : 25972.05
# Lifestyle : 8978.308510638299
# Entertainment : 10822.961077844311
# Food & Drink : 20179.093023255813
# Sports : 20128.974683544304
# Book : 8498.333333333334
# Finance : 13522.261904761905
# Education : 6266.333333333333
# Productivity : 19053.887096774193
# Business : 6367.8
# Catalogs : 1779.5555555555557
# Medical : 459.75

# %% [markdown]
# On average,  Music App has the highest user reviews which is why I will recommend the Music App profle for the App store

# %%
display_table(free_apps, 5) # The Installs columns
# Out:
# 1,000,000+ 1555
# 10,000,000+ 1249
# 100,000+ 1079
# 10,000+ 925
# 1,000+ 758
# 5,000,000+ 752
# 100+ 623
# 500,000+ 527
# 50,000+ 436
# 5,000+ 410
# 100,000,000+ 409
# 10+ 316
# 500+ 290
# 50,000,000+ 289
# 50+ 171
# 500,000,000+ 72
# 5+ 70
# 1,000,000,000+ 58
# 1+ 46
# 0+ 4
# 0 1

# %% [markdown]
# Computing the Average number of Installs per App genre for the Google Play Dataset

# %%
category_unique = freq_table(free_apps, 1)

for category in category_unique:
    total = 0
    len_category = 0
    for element in free_apps:
        category_app = element[1]
        if category_app == category:
            n_installs = element[5]
            n_installs = float(n_installs.replace('+', '').replace(',', ''))
            total += n_installs
            len_category += 1
    average_installs = total / len_category
    print(category, ': ',average_installs)
# Out:
# ART_AND_DESIGN :  2005195.1612903227
# AUTO_AND_VEHICLES :  647317.8170731707
# BEAUTY :  513151.88679245283
# BOOKS_AND_REFERENCE :  9465252.512315271
# BUSINESS :  2245520.3811659194
# COMICS :  934769.1666666666
# COMMUNICATION :  90683100.55833334
# DATING :  1164270.7356828193
# EDUCATION :  5729276.315789473
# ENTERTAINMENT :  19516734.69387755
# EVENTS :  253542.22222222222
# FINANCE :  2511355.6790830945
# FOOD_AND_DRINK :  2190710.008
# HEALTH_AND_FITNESS :  4869225.852307692
# HOUSE_AND_HOME :  1917187.0568181819
# LIBRARIES_AND_DEMO :  749950.119047619
# LIFESTYLE :  1477863.44077135
# GAME :  33048939.16116871
# FAMILY :  5742274.952835485
# MEDICAL :  147563.28813559323
# SOCIAL :  48184458.56849315
# SHOPPING :  12588522.03488372
# PHOTOGRAPHY :  32218111.54952077
# SPORTS :  4860918.563888889
# TRAVEL_AND_LOCAL :  27921561.32520325
# TOOLS :  14968685.586928105
# PERSONALIZATION :  7508854.330097088
# PRODUCTIVITY :  35794644.73232323
# PARENTING :  542603.6206896552
# WEATHER :  5747142.162162162
# VIDEO_PLAYERS :  36385565.614035085
# NEWS_AND_MAGAZINES :  26677267.829181496
# MAPS_AND_NAVIGATION :  5486066.590909091

# %% [markdown]
# Communication apps typically have 38,456,119 installs, which is the most. A few apps (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts) with over one billion installs and a few others with between 100 million and 500 million installs significantly distort this number:
